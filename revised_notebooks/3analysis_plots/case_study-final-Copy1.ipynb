# %%
import datetime as dt
import os, sys
import netCDF4 as nc
import matplotlib as mpl
import numpy as np
import numpy.ma as ma
from scipy.spatial import distance
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.patches import Ellipse
from matplotlib import cm
import matplotlib.colors as mpl_colors
from matplotlib import rc
from mpl_toolkits.axes_grid1 import make_axes_locatable
from dateutil.relativedelta import relativedelta



import numpy as np
import datetime as dtm
import dateutil.parser as dparser
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# from mpl_toolkits.basemap import Basemap (rotate, ben's suggestion)



from salishsea_tools import geo_tools, viz_tools

get_ipython().magic('matplotlib inline')

# %%
filesdir = "/ocean/gsgarbi/selected_days/"

dirs = os.listdir(filesdir)



Iona = (-123.30898284912109, 49.187351226806641)
S15 = (-123.3114, 49.130412)
S16 = (-123.317415, 49.1214)
xl=(-126.2,-122.2)
yl=(47.1,51)

# %%
def param(timef, date): #background
    
    size = 5
    ms = 5
    S15 = (-123.3114, 49.130412)
    S16 = (-123.317415, 49.1214) 
    bathy = nc.Dataset("/ocean/gsgarbi/bathy_meter_SalishSea2.nc")
    model_lats = bathy.variables['nav_lat'][:]
    model_lons = bathy.variables['nav_lon'][:]
    depth = bathy.variables['Bathymetry'][:]        
    #End of spit
    late = 49.205
    lone = -123.26
    #Further up spit
    lats = 49.214
    lons = -123.22
        
    dx = 1.2
    lat = late + dx * (late - lats)
    lon = lone + dx * (lone - lons)
    y, x = geo_tools.find_closest_model_point(lon, lat, model_lons, model_lats)

    outy = y - 1
    outx = x - 1
    
    deep = 110
    shallow = 35
    
    time_0 = 0
    
    time_f = 2
    
    new_limx = (-124.5,-122.5)
    
    new_limy = (48.7,49.5)

    
    new_ticksx = (new_limx[0], float(sum(new_limx))/2, new_limx[1])
    
    new_ticksy = (new_limy[0], float(sum(new_limy))/2, new_limy[1])
                       
    
    Iona =(model_lons[outy, outx], model_lats[outy, outx])
    
    
    
    #norm_p = mpl_colors.Normalize(vmin=deep, vmax=shallow)
    
    norm_w = None
    cmap_w = "winter_r"
    
    norm_p = mpl_colors.Normalize(vmin=time_0, vmax=timef*24)
    cmap_p = plt.cm.plasma_r
      

    
   

        
    global fig, axs
    
    fig, axs = plt.subplots(LIN,COL, figsize = (5,4))

    
    if LIN == 1 or COL == 1:
        
        axs=np.reshape(axs,(1,1))
    
    
    
    for j in range(LIN):
        for k in range (COL):
            
            divider = make_axes_locatable(axs[j,k])
            
            cax_w = divider.append_axes("right", size="5%", pad=0.05)
            
            cax_p = divider.append_axes("bottom", size="5%", pad=0.5)
            
            
            cb_w = mpl.colorbar.ColorbarBase(cax_w, 
                                             cmap = mpl.cm.get_cmap('winter_r'),
                                             norm = mpl.colors.Normalize(vmin=shallow, 
                                                                         vmax=deep),
                                             orientation='vertical')

            
            cb_p = mpl.colorbar.ColorbarBase(cax_p, 
                                             cmap = plt.cm.plasma_r,
                                             norm = mpl.colors.Normalize(vmin=0, vmax=timef*24), 
                                            #vmax=date + dt.timedelta(hours = timef*24)),
                                             orientation='horizontal')
            
            
            
            
            
            
            cb_w.set_label("Water depth (m)")
            
            cb_p.set_label("Time (GMT)")
    
    
    
    
            mesh_w = axs[j,k].pcolormesh(model_lons, model_lats, depth, cmap=cmap_w)
    

            
    
            axs[j,k].set_xlim(new_limx)
            axs[j,k].set_xticks(new_ticksx)
            axs[j,k].set_xticklabels(('%s W' %-new_limx[0], 
                                      '%s W' %-round(float(sum(new_limx))/2,2), 
                                      '%s W' %-new_limx[1]))
            axs[j,k].set_xlabel('Longitude')
            
            axs[j,k].set_ylim(new_limy)
            axs[j,k].set_yticks(new_ticksy)
            axs[j,k].set_yticklabels(('%s N' %new_limy[0], 
                                      '%s N' %round(float(sum(new_limy))/2,1), 
                                      '%s N' %new_limy[1]))
            axs[j,k].set_ylabel('Latitude')
            
            
            #Iona
            axs[j,k].plot(Iona[0], Iona[1], 'wo', ms = ms)
            #New Stations
    
            axs[j,k].plot(S15[0],S15[1], 'wo', ms = ms)
            
            axs[j,k].plot(S16[0],S16[1], 'wo', ms = ms)
            
            axs[j,k].annotate(
            "Iona outfall",
            xy=(model_lons[outy, outx], model_lats[outy, outx]), xytext=(50, 10),
            textcoords='offset points', ha='left', va='bottom',
            #bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
            arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
            
            axs[j,k].annotate(
            "Station 15",
            xy=(S15[0],S15[1]), xytext=(50, 10),
            textcoords='offset points', ha='left', va='bottom',
            #bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
            arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
    
            axs[j,k].annotate(
            "Station 16",
            xy=(S16[0],S16[1]), xytext=(50, 10),
            textcoords='offset points', ha='left', va='top',
            #bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
            arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
        
    

    return axs

# In[31]:|

# %%
# #72 particulas por dia e 72 pontos por dia por trajetoria

RAWDIR = "/ocean/gsgarbi/ariane_raw/2016+jan2017/"
    
OUTPUTDIR = "/ocean/gsgarbi/selected_days/"

H = 24

pph = 3

ppd = H * pph #(also number of outputs per trajectory per day since we have 3 outputs per hour)

# %%
def find_direct (RAWDIR, date, traj_len):
    init_date = date - dt.timedelta(days = traj_len)
    y = str(init_date.year)
    m = str(init_date.month)
    n = str(date.month)
    w = str(date.year)
    


    if len (m) == 1:
        m = "0"+str(m)
        
    if len (n) == 1:
        n = "0"+str(n)
    
    direct = [i for i in os.listdir(RAWDIR) if y+m == i[:6] or w+n == i[:6] ]
    
    print ("got directory")
    
    return direct

# %%
def get_points(direct, date, traj_len):
    '''
    get pts with fixed traj len
    '''
    pts = []
    init_date = date - dt.timedelta(days = traj_len)
    d = init_date.day
    parts = range (1 + ppd*(d - 1), 1 + ppd*(d - 1) + traj_len * ppd)
    part = parts[0]
    print ("initial date: ", init_date, "\n",
              "final date: ", date, "\n",
              "traj len: ", traj_len,
              "particule #: from {} to {} ".format(1 + ppd*(d - 1), 
                                                   1 + ppd*(d - 1) + traj_len * ppd),
                "num particules: ", traj_len * ppd
              )
    
    allparts = []
    
    for directory in direct:


        with open(RAWDIR + directory + "/traj.txt") as file:



            count = 0
            traj = []


            for i, line in enumerate(file):  
                line = line.strip('\n').split()
                line = [float(k) for k in line]


                if line[0] == part:

                    traj.append(line)
                    count +=1
                if count == traj_len * ppd:
                    allparts.append (part) #72, 71, 70,...
                    pts.append(traj)
                    traj = [] #reset traj
                    count = 0 #reset counter
                    part += 1 #go to the next particle
                    #traj_len -= int(i/3) * 3 #next length will be smaller
                if part == parts[-1]+1:
                    break
            else:
                    print ("month transition -> open next file")


                    parts = range (1, 1 + ppd*(d - 1) + traj_len * ppd - part)
                    part = parts[0]

                




    return pts

# %%
LIN = 1
COL = 1

# %%
traj_len = 3

times = np.array(
    [
    dt.datetime(2016, 7, 19),
    dt.datetime(2016, 7, 26),
    dt.datetime(2016, 8, 2),
    dt.datetime(2016, 8, 9),
    dt.datetime(2016, 8, 16),
    dt.datetime(2016, 8, 23),
    ]
                            )

init_depths = [45,59,77]

test = times_day_before = np.array(
    [


        dt.datetime(2016, 8, 2),


    ]
                            )


for date in test:
    
    print (date)



    direct = find_direct(RAWDIR, date, traj_len)
    print ("direct: ", direct)



    pts = get_points(direct, date, traj_len)




    init_date = date - dt.timedelta(days = traj_len)

    for i_0 in range(3):
        


        axs = param(traj_len, init_date)
        
                    



        for num, part in enumerate(pts[i_0::3]):
            

            END = traj_len*H*(60/20)
            print ("cbar. END:", END)
            START = part[0][0] #particule number for 1st particule
        
            print ("cbar. first particule:", START)

            
            
            part = part[:-(num*3 +1)] #cut the end of traj

            end = len(part)
            
            
            print ("traj num: ", num, "traj len: ", end)
            

            

            


            for t in range (end): #part is a trajectory
                
                t_color = t + 3*(part[t][0] - START) #add initial time
                

                scaled_t = 1-(END - t_color) / END
                #print ("scaled_t", scaled_t)
                cmap = plt.cm.plasma_r
                color = cmap(scaled_t)
                axs[0,0].scatter(part[t][1], part[t][2], s = 2,
                                 c = color, edgecolor = None)
                fdate1 = date.strftime('%m/%d/%Y')
                fdate2 = date.strftime('%m_%d_%Y')
                
                axs[0,0].set_title(fdate1 + 
                                   " - Initial depth: {} m".format(init_depths[i_0]),
                                  fontsize = 14) 

                                                        
            print ("end of trajectory ------------------")
        
        plt.savefig(fig.savefig(
            "/ocean/gsgarbi/MEOPAR/private-docs/reports"+
            "/IonaProject/ionafigs/cs_{}_{}d_{}.png".format(fdate2, 
                                                         traj_len, 
                                                         init_depths[i_0]) ), dpi = 400 )
        
        plt.show()




#         viz_tools.set_aspect(axs[0,0])
# Out:
# 2016-08-02 00:00:00
# got directory
# direct:  ['20160801_20160831_217d', '20160701_20160731_252d']
# initial date:  2016-07-30 00:00:00
#  final date:  2016-08-02 00:00:00
#  traj len:  3 particule #: from 2089 to 2305  num particules:  216
# month transition -> open next file
# cbar. END: 216.0
# cbar. first particule: 2089.0
# traj num:  0 traj len:  215
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2092.0
# traj num:  1 traj len:  212
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2095.0
# traj num:  2 traj len:  209
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2098.0
# traj num:  3 traj len:  206
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2101.0
# traj num:  4 traj len:  203
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2104.0
# traj num:  5 traj len:  200
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2107.0
# traj num:  6 traj len:  197
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2110.0
# traj num:  7 traj len:  194
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2113.0
# traj num:  8 traj len:  191
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2116.0
# traj num:  9 traj len:  188
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2119.0
# traj num:  10 traj len:  185
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2122.0
# traj num:  11 traj len:  182
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2125.0
# traj num:  12 traj len:  179
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2128.0
# traj num:  13 traj len:  176
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2131.0
# traj num:  14 traj len:  173
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2134.0
# traj num:  15 traj len:  170
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2137.0
# traj num:  16 traj len:  167
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2140.0
# traj num:  17 traj len:  164
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2143.0
# traj num:  18 traj len:  161
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2146.0
# traj num:  19 traj len:  158
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2149.0
# traj num:  20 traj len:  155
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2152.0
# traj num:  21 traj len:  152
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2155.0
# traj num:  22 traj len:  149
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2158.0
# traj num:  23 traj len:  146
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 1.0
# traj num:  24 traj len:  143
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 4.0
# traj num:  25 traj len:  140
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 7.0
# traj num:  26 traj len:  137
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 10.0
# traj num:  27 traj len:  134
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 13.0
# traj num:  28 traj len:  131
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 16.0
# traj num:  29 traj len:  128
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 19.0
# traj num:  30 traj len:  125
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 22.0
# traj num:  31 traj len:  122
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 25.0
# traj num:  32 traj len:  119
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 28.0
# traj num:  33 traj len:  116
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 31.0
# traj num:  34 traj len:  113
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 34.0
# traj num:  35 traj len:  110
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 37.0
# traj num:  36 traj len:  107
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 40.0
# traj num:  37 traj len:  104
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 43.0
# traj num:  38 traj len:  101
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 46.0
# traj num:  39 traj len:  98
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 49.0
# traj num:  40 traj len:  95
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 52.0
# traj num:  41 traj len:  92
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 55.0
# traj num:  42 traj len:  89
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 58.0
# traj num:  43 traj len:  86
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 61.0
# traj num:  44 traj len:  83
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 64.0
# traj num:  45 traj len:  80
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 67.0
# traj num:  46 traj len:  77
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 70.0
# traj num:  47 traj len:  74
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 73.0
# traj num:  48 traj len:  71
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 76.0
# traj num:  49 traj len:  68
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 79.0
# traj num:  50 traj len:  65
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 82.0
# traj num:  51 traj len:  62
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 85.0
# traj num:  52 traj len:  59
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 88.0
# traj num:  53 traj len:  56
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 91.0
# traj num:  54 traj len:  53
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 94.0
# traj num:  55 traj len:  50
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 97.0
# traj num:  56 traj len:  47
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 100.0
# traj num:  57 traj len:  44
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 103.0
# traj num:  58 traj len:  41
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 106.0
# traj num:  59 traj len:  38
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 109.0
# traj num:  60 traj len:  35
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 112.0
# traj num:  61 traj len:  32
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 115.0
# traj num:  62 traj len:  29
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 118.0
# traj num:  63 traj len:  26
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 121.0
# traj num:  64 traj len:  23
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 124.0
# traj num:  65 traj len:  20
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 127.0
# traj num:  66 traj len:  17
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 130.0
# traj num:  67 traj len:  14
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 133.0
# traj num:  68 traj len:  11
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 136.0
# traj num:  69 traj len:  8
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 139.0
# traj num:  70 traj len:  5
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 142.0
# traj num:  71 traj len:  2
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2090.0
# traj num:  0 traj len:  215
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2093.0
# traj num:  1 traj len:  212
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2096.0
# traj num:  2 traj len:  209
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2099.0
# traj num:  3 traj len:  206
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2102.0
# traj num:  4 traj len:  203
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2105.0
# traj num:  5 traj len:  200
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2108.0
# traj num:  6 traj len:  197
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2111.0
# traj num:  7 traj len:  194
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2114.0
# traj num:  8 traj len:  191
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2117.0
# traj num:  9 traj len:  188
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2120.0
# traj num:  10 traj len:  185
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2123.0
# traj num:  11 traj len:  182
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2126.0
# traj num:  12 traj len:  179
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2129.0
# traj num:  13 traj len:  176
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2132.0
# traj num:  14 traj len:  173
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2135.0
# traj num:  15 traj len:  170
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2138.0
# traj num:  16 traj len:  167
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2141.0
# traj num:  17 traj len:  164
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2144.0
# traj num:  18 traj len:  161
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2147.0
# traj num:  19 traj len:  158
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2150.0
# traj num:  20 traj len:  155
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2153.0
# traj num:  21 traj len:  152
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2156.0
# traj num:  22 traj len:  149
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2159.0
# traj num:  23 traj len:  146
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2.0
# traj num:  24 traj len:  143
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 5.0
# traj num:  25 traj len:  140
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 8.0
# traj num:  26 traj len:  137
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 11.0
# traj num:  27 traj len:  134
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 14.0
# traj num:  28 traj len:  131
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 17.0
# traj num:  29 traj len:  128
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 20.0
# traj num:  30 traj len:  125
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 23.0
# traj num:  31 traj len:  122
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 26.0
# traj num:  32 traj len:  119
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 29.0
# traj num:  33 traj len:  116
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 32.0
# traj num:  34 traj len:  113
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 35.0
# traj num:  35 traj len:  110
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 38.0
# traj num:  36 traj len:  107
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 41.0
# traj num:  37 traj len:  104
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 44.0
# traj num:  38 traj len:  101
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 47.0
# traj num:  39 traj len:  98
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 50.0
# traj num:  40 traj len:  95
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 53.0
# traj num:  41 traj len:  92
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 56.0
# traj num:  42 traj len:  89
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 59.0
# traj num:  43 traj len:  86
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 62.0
# traj num:  44 traj len:  83
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 65.0
# traj num:  45 traj len:  80
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 68.0
# traj num:  46 traj len:  77
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 71.0
# traj num:  47 traj len:  74
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 74.0
# traj num:  48 traj len:  71
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 77.0
# traj num:  49 traj len:  68
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 80.0
# traj num:  50 traj len:  65
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 83.0
# traj num:  51 traj len:  62
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 86.0
# traj num:  52 traj len:  59
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 89.0
# traj num:  53 traj len:  56
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 92.0
# traj num:  54 traj len:  53
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 95.0
# traj num:  55 traj len:  50
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 98.0
# traj num:  56 traj len:  47
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 101.0
# traj num:  57 traj len:  44
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 104.0
# traj num:  58 traj len:  41
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 107.0
# traj num:  59 traj len:  38
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 110.0
# traj num:  60 traj len:  35
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 113.0
# traj num:  61 traj len:  32
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 116.0
# traj num:  62 traj len:  29
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 119.0
# traj num:  63 traj len:  26
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 122.0
# traj num:  64 traj len:  23
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 125.0
# traj num:  65 traj len:  20
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 128.0
# traj num:  66 traj len:  17
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 131.0
# traj num:  67 traj len:  14
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 134.0
# traj num:  68 traj len:  11
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 137.0
# traj num:  69 traj len:  8
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 140.0
# traj num:  70 traj len:  5
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 143.0
# traj num:  71 traj len:  2
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2091.0
# traj num:  0 traj len:  215
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2094.0
# traj num:  1 traj len:  212
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2097.0
# traj num:  2 traj len:  209
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2100.0
# traj num:  3 traj len:  206
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2103.0
# traj num:  4 traj len:  203
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2106.0
# traj num:  5 traj len:  200
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2109.0
# traj num:  6 traj len:  197
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2112.0
# traj num:  7 traj len:  194
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2115.0
# traj num:  8 traj len:  191
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2118.0
# traj num:  9 traj len:  188
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2121.0
# traj num:  10 traj len:  185
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2124.0
# traj num:  11 traj len:  182
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2127.0
# traj num:  12 traj len:  179
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2130.0
# traj num:  13 traj len:  176
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2133.0
# traj num:  14 traj len:  173
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2136.0
# traj num:  15 traj len:  170
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2139.0
# traj num:  16 traj len:  167
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2142.0
# traj num:  17 traj len:  164
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2145.0
# traj num:  18 traj len:  161
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2148.0
# traj num:  19 traj len:  158
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2151.0
# traj num:  20 traj len:  155
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2154.0
# traj num:  21 traj len:  152
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2157.0
# traj num:  22 traj len:  149
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 2160.0
# traj num:  23 traj len:  146
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 3.0
# traj num:  24 traj len:  143
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 6.0
# traj num:  25 traj len:  140
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 9.0
# traj num:  26 traj len:  137
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 12.0
# traj num:  27 traj len:  134
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 15.0
# traj num:  28 traj len:  131
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 18.0
# traj num:  29 traj len:  128
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 21.0
# traj num:  30 traj len:  125
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 24.0
# traj num:  31 traj len:  122
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 27.0
# traj num:  32 traj len:  119
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 30.0
# traj num:  33 traj len:  116
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 33.0
# traj num:  34 traj len:  113
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 36.0
# traj num:  35 traj len:  110
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 39.0
# traj num:  36 traj len:  107
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 42.0
# traj num:  37 traj len:  104
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 45.0
# traj num:  38 traj len:  101
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 48.0
# traj num:  39 traj len:  98
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 51.0
# traj num:  40 traj len:  95
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 54.0
# traj num:  41 traj len:  92
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 57.0
# traj num:  42 traj len:  89
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 60.0
# traj num:  43 traj len:  86
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 63.0
# traj num:  44 traj len:  83
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 66.0
# traj num:  45 traj len:  80
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 69.0
# traj num:  46 traj len:  77
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 72.0
# traj num:  47 traj len:  74
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 75.0
# traj num:  48 traj len:  71
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 78.0
# traj num:  49 traj len:  68
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 81.0
# traj num:  50 traj len:  65
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 84.0
# traj num:  51 traj len:  62
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 87.0
# traj num:  52 traj len:  59
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 90.0
# traj num:  53 traj len:  56
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 93.0
# traj num:  54 traj len:  53
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 96.0
# traj num:  55 traj len:  50
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 99.0
# traj num:  56 traj len:  47
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 102.0
# traj num:  57 traj len:  44
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 105.0
# traj num:  58 traj len:  41
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 108.0
# traj num:  59 traj len:  38
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 111.0
# traj num:  60 traj len:  35
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 114.0
# traj num:  61 traj len:  32
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 117.0
# traj num:  62 traj len:  29
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 120.0
# traj num:  63 traj len:  26
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 123.0
# traj num:  64 traj len:  23
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 126.0
# traj num:  65 traj len:  20
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 129.0
# traj num:  66 traj len:  17
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 132.0
# traj num:  67 traj len:  14
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 135.0
# traj num:  68 traj len:  11
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 138.0
# traj num:  69 traj len:  8
# end of trajectory ------------------
# cbar. END: 216.0
# cbar. first particule: 141.0
# traj num:  70 traj len:  5
# end of trajectory ------------------

# %%
print ("ionafigs/cs_{}_{}d_{}.png".format(fdate2, 
                                                         traj_len, 
                                                         init_depths[i_0]))
# Out:
# ionafigs/cs_07_19_2016_3d_77.png
