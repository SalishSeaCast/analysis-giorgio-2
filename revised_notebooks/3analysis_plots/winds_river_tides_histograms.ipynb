# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import numpy as np
import datetime
import os
import glob
import csv
import pandas as pd
from dateutil import tz
import datetime as dt
import seaborn as sns
import pickle

from salishsea_tools import tidetools, places, geo_tools, viz_tools
import matplotlib.dates as md

from dateutil.relativedelta import relativedelta

# %matplotlib inline

# %% [markdown]
# <b> Constants <b>

# %%
start = dt.datetime(2016, 7, 1, 0, 0)
end = dt.datetime(2016, 9, 30)



Iona = (-123.30807, 49.19026) #value from first point in traj.txt (Ariane output)

S15 = (-123.3114, 49.130412)
S16 = (-123.317415, 49.1214)
xl=(-126.2,-122.2)
yl=(47.1,51)

RAWDIR = "/ocean/gsgarbi/ariane_raw/2016+jan2017/"
    
OUTPUTDIR = "/ocean/gsgarbi/selected_days/"

H = 24

pph = 3

ppd = H * pph #(also number of outputs per trajectory per day since we have 3 outputs per hour)

# %% [markdown]
# Nancy's adapted functions

# %%
def list_wind_files(
    to, tf,
    wind_dir='/results/forcing/atmospheric/GEM2.5/operational/'
):
    """List operational wind files in date range [to, tf]

    :arg to: beginning of date range
    :type to: datetime object

    :arg tf: end of date range
    :type tf: datetime object

    :arg wind_dir: directory were wind files are stored
    :type wind_dir: str

    :returns: filesOP, a list of files in date range
    """

           
    sstr = to.strftime('ops_y%Ym%md%d.nc')
    estr = tf.strftime('ops_y%Ym%md%d.nc')
    files = glob.glob(os.path.join(wind_dir, 'ops_*.nc'))

    filesOP = []

    for filename in files:

        if os.path.basename(filename) >= sstr:
            if os.path.basename(filename) <= estr:
                filesOP.append(filename)

        filesOP.sort(key=os.path.basename)        

        
    
    filesOP.sort(key=os.path.basename)
    return filesOP

       
        

def compile_winds_study(j, i, files, study):
    """
    Compile a time series of operational atmospheric products stored in files
    at grid point j, i. First 24 hours of each file are used

    :arg j: the y-index of the grid point
    :type j: non-negative integer

    :arg i: the x-index of the grid point
    :type i: non-negative interger

    :arg files: list of atmospheric operational files
    :type files: list

    :returns: wind, direc, t, pr, tem, sol, the, qr, pre, all arrays
    wind speed, diretion, time, pressure, temperature, solar radiation,
    humidity, precipitation.

    """
    wind = []
    direc = []
    t = []
    pr = []
    sol = []
    the = []
    pre = []
    tem = []
    qr = []
    
    hours_dict = separate(study)
    
    
    
    for f in files:
        G = nc.Dataset(f)
        d = int(f [-5:-3])
        m = int(f [-8:-6])
        y = int(f [-13: -9])
        
        date = dt.date(y, m, d)
        
        if date in hours_dict.keys():
        
            hours = hours_dict[date]
        
        else:
            continue
            
        
        u = []
        v = []
        for h in hours:
            u.append(G.variables['u_wind'][h, j, i])
            v.append(G.variables['v_wind'][h, j, i])
        
        u = np.array(u)
        v = np.array(v)
        
        speed = np.sqrt(u**2 + v**2)
        wind.append(speed)


        d = np.arctan2(v, u)
        d = np.rad2deg(d + (d < 0)*2*np.pi)
        direc.append(d)


#     wind = np.array(wind).reshape(numdays*24,)
#    direc = np.array(direc, 'double').reshape(numdays*24,)
#     t = np.array(t).reshape(numdays*24,)
#     pr = np.array(pr).reshape(numdays*24,)
#     tem = np.array(tem).reshape(numdays*24,)
#     sol = np.array(sol).reshape(numdays*24,)
#     the = np.array(the).reshape(numdays*24,)
#     qr = np.array(qr).reshape(numdays*24,)
#     pre = np.array(pre).reshape(numdays*24,)

    return wind, direc

def find_model_point(lon, lat, X, Y, tol_lon=0.016, tol_lat=0.011):
    """Finds a model grid point close to a specified latitude and longitude.
    Should be used for non-NEMO grids like the atmospheric forcing grid.

    :arg lon: The longitude we are trying to match.
    :type lon: float

    :arg lat: The latitude we are trying to match.
    :type lat: float

    :arg X: The model longitude grid.
    :type X: numpy array

    :arg Y: The model latitude grid.
    :type Y: numpy array

    :arg tol_lon: tolerance on grid spacing for longitude
    :type tol_lon: float

    :arg tol_lat: tolerance on grid spacing for latitude
    :type tol_lat: float

    :returns: j-index and i-index of the closest model grid point.
    """

    # Search for a grid point with longitude or latitude within
    # tolerance of measured location
    j, i = np.where(
        np.logical_and(
            (np.logical_and(X > lon - tol_lon, X < lon + tol_lon)),
            (np.logical_and(Y > lat - tol_lat, Y < lat + tol_lat))))

    if j.size > 1 or i.size > 1:
        raise ValueError(
            'Multiple model points found. tol_lon/tol_lat too big.'
        )
    elif not j or not i:
        raise ValueError(
            'No model point found. tol_lon/tol_lat too small or '
            'lon/lat outside of domain.'
        )
    return j, i



def dateParserMeasured2(s):
    """
    converts string in %d-%b-%Y %H:%M:%S format Pacific time to a
    datetime object UTC time.
    """
    PST = tz.tzoffset("PST", -28800)
    # convert the string to a datetime object
    unaware = datetime.datetime.strptime(s, "%d-%b-%Y %H:%M:%S ")
    # add in the local time zone (Canada/Pacific)
    aware = unaware.replace(tzinfo=PST)
    # convert to UTC
    return aware.astimezone(tz.tzutc())

# %% [markdown]
# Get points and separate them according to chosen criteria.

# %%
def find_direct (RAWDIR, date, traj_len):
    'traj len needs to be equal to or less than 30 (days)'
    start = date
    end = date + dt.timedelta(days = traj_len) 
    y = str(start.year)
    m = str(start.month)
    n = str(end.month)
    w = str(end.year)
    


    if len (m) == 1:
        m = "0"+str(m)
        
    if len (n) == 1:
        n = "0"+str(n)
    
    direct = [ i for i in os.listdir(RAWDIR) if y+m == i[:6] or w+n == i[:6] ]
    
    direct = sorted(direct)
    
    print ("got directory(ies)")
    
    return direct

# %%
def get_points(direct, init_date, traj_len, phase = 0):
    '''
    get 72 trajs (3 per hour) starting on date.day with fixed traj len
    '''
    
    date0 = dt.datetime( init_date.year, init_date.month, 1, 0, 0)
    
    phase = phase * 3
    pts = []

    d = init_date.day
    #select the particles
    parts = range (1 + ppd*(d - 1) + phase, 1 + ppd*(d - 1) + phase + 72)

    part = parts[0]
    

    for directory in direct:


        with open(RAWDIR + directory + "/traj.txt") as file:
            
            

            count = 0
            traj = []
            
            date0 += relativedelta( months = direct.index(directory) )

            
            
            for i, line in enumerate(file):

                line = line.strip('\n').split()
                line = [float(k) for k in line]


                if line[0] == part:
                    

                    
                    mins0 = 60*int( (part-1)/3 )
                    
                    time = date0 + dt.timedelta( minutes = mins0) + dt.timedelta( minutes = count * 20)
                    
                    
                    traj.append(line + [time])
                    

                    count +=1
                if count == traj_len * ppd:

                    pts.append(traj)
                    traj = [] #reset traj
                    count = 0 #reset counter
                    part += 1 #go to the next particle

                if part == parts[-1]+1:
                    break
            else:
                    print ("month transition -> open next file")
                    


                    parts = range (1, parts[-1] - part)
                    part = parts[0]

    return pts

# %% [markdown]
# Trajectory analysis

# %%
def dist(p, q = S15):
    d = geo_tools.haversine (p[1],p[2], q[0], q[1])
    return d

# %%
def traj_analysis (traj, time = 24, distance = 1.2):

    age = 0
    
    date = [ traj[0][-1] + dt.timedelta(hours = h) for h in range (24) ] 
    
    for pt in traj:
        

        if (dist(pt, S15) < distance or dist(pt, S16) < distance) and traj.index(pt)/3 < time:

            
            age = traj.index(pt)/3
            break
    return (date, age)

# %%
def separate (study):
    dd = {}
    dates = [k.date() for k in study]
    for date in set(dates):
        dd[date] = []
    
    for date in study:
        dd[date.date()].append(int(date.hour))
        

        
    return dd

# %% [markdown]
# Analysis

# %%
def save_trajs (start, end, traj_len, direct):
    pts = []

    date = start


    while date != end + dt.timedelta(days=1):

        direct = find_direct(RAWDIR, date, traj_len)

        pts.append(get_points(direct, date, traj_len, phase = 0))

        date = date + dt.timedelta (days = 1)


    full_period = [k for sublist in pts for k in sublist]

    with open(fullperiod_direct, 'wb') as fp:
        pickle.dump(full_period, fp)

# %%
def load_river_flow(file_loc, date0, datef):
    
    results = []
    
    date = date0
    
    
    while date != datef + datetime.timedelta(days = 1):
    
        year = date.year
        mon = date.month
        day = date.day



        with open(file_loc) as file:
            for line in file:
                line = line.strip('\n').split()
                linedata = [int(k) for k in line[0:3]]
                
                if linedata == [year, mon, day]:
                    results.append(linedata + [float(line[3])])
    
        date = date + datetime.timedelta(days=1)
        
    return results

# %%
def to_hours (date, date0= start):
    return int((date - date0).total_seconds() / 3600)

def to_dt (hours, date0 = start):
    return date0 + dt.timedelta(hours = hours)

# %%
# save_trajs (start = start, end = end, traj_len = traj_len, direct = fullperiod_direct)

# %% [markdown]
# We can start here after we have full_period

# %%
traj_len = 1 #24 hours
fullperiod_direct = '/ocean/gsgarbi/revised_notebooks/3analysis_plots/jun_sep_nolastdays_trajlen{}d.npy'.format(traj_len)
with open (fullperiod_direct, 'rb') as fp:
    full_period = pickle.load(fp)

# %%
results = []

for traj in full_period:
    results.append(traj_analysis(traj))

results = np.array(results)

# %%
control = []
study = []
for i in results:
    if i [1] == 0:
        control.append(i[0])
    else:
        study.append(i[0])

study_points = [k for sublist in study for k in sublist]
control_points = [k for sublist in control for k in sublist]

# %%
study_dictionary = separate (study_points)
study_dates = [key for key in study_dictionary.keys()]


control_dictionary = separate (control_points)


control_dates = [key for key in control_dictionary.keys()]

# %%
#Iona = (-123.30898284912109, 49.187351226806641)
Iona = (-123.30807, 49.19026) #value from first point in traj.txt (Ariane output)


sdt = start
edt = end

OP = nc.Dataset('/ocean/gsgarbi/ops_y2014m11d18.nc')
OPlon =OP.variables['nav_lon'][:]-360
OPlat = OP.variables['nav_lat'][:]

lons, lats = OPlon, OPlat

lon, lat = [Iona[0], Iona[1]]
wind_files = list_wind_files(sdt, edt)


j,i=find_model_point(lon,lat,lons,lats)

windS, direcS = compile_winds_study(j,i,wind_files, study_points)
windC, direcC = compile_winds_study(j,i,wind_files, control_points)

# %%
study_group = [k for sublist in windS for k in sublist ]
control_group = [k for sublist in windC for k in sublist ]

for i in range (2):                    
    study_group = [k for sublist in study_group for k in sublist ]
    control_group = [k for sublist in control_group for k in sublist ]

# %%
fig, axs = plt.subplots(1,1, figsize = (8,7))

labels = ('Other trajectories', 'Southern trajectories')

groups = [control_group, study_group]

colors = ['b','r']





axs.hist(
        groups, 
        color= colors, 
        alpha=0.8, 
        normed = True,
        label = labels, 
        )

axs.set_ylabel ("Percentage of trajectories")
axs.set_xlabel ("Wind speed in m/s measured at Iona at the start of the trajectory")

axs.set_title ('Wind speed \n June 1 - September 30', size = 18)


plt.legend()

# %%
study_group = [k for sublist in direcS for k in sublist ]
control_group = [k for sublist in direcC for k in sublist ]

for i in range (2):                    
    study_group = [k for sublist in study_group for k in sublist ]
    control_group = [k for sublist in control_group for k in sublist ]

# %%
fig, axs = plt.subplots(1,1, figsize = (8,7))

labels = ('Other trajectories', 'Southern trajectories')

groups = [control_group, study_group]

colors = ['b','r']





axs.hist(
        groups, 
        color= colors, 
        alpha=0.8, 
        normed = True,
        label = labels, 
        )

axs.set_ylabel ("Percentage of trajectories")
axs.set_xlabel ("Wind direction in degrees (counterclockwise from East) at Iona at the start of the trajectory")

axs.set_title ('Wind direction \n June 1 - September 30', size = 18)


plt.legend()

# %% [markdown]
# Fraser River flow comparison between south and non-south trajectories

# %%
river = load_river_flow('/ocean/gsgarbi/Fraser_flow', start, end)

river_data = np.array([(dt.datetime(day = k[2], month = k[1], year = k[0]), k[3]) for k in river])

river_dates = river_data[:,0]
H = list(map(to_hours, river_dates))
date0 = river_dates[0]
datef = river_dates[-1]
river_flow = list(river_data[:,1])
points = list(range ( ((datef-date0).days + 1) * 24)) #list in hours

# %%
def interp (point, H = H, river_flow = river_flow):
    return np.interp(point, H, river_flow)

# %%
values = list(map (interp, points))

# %%
all_dts = list(map(to_dt, points))

# %%
#check if interpolation worked
fig, axs = plt.subplots(1,2, figsize =(12,5))
axs[0].plot(all_dts, values)
axs[0].set_title('Interpolation')
axs[1].plot(river_data[:,0], river_data[:,1])
axs[1].set_title('Expected')
plt.tight_layout()

# %%
rand = np.random.randint(0, len(river_data))
p1 = river_data[rand,0]
p1_value = river_data[rand,1]

p2 = river_data[rand+1,0]
p2_value = river_data[rand+1,1]

test_point = p1 + dt.timedelta(hours = np.random.randint(0, 24))
test_value = interp(to_hours(test_point))



print (
    'p1 = {} -> {}\np2 = {} -> {}\ninterpolated point = {} -> {}'.format(
    p1, p1_value,
    p2, p2_value,
    test_point, test_value
) )
# Out:
# p1 = 2016-07-11 00:00:00 -> 4292.124
# p2 = 2016-07-12 00:00:00 -> 4141.267
# interpolated point = 2016-07-11 16:00:00 -> 4191.5526666666665

# %%
river_hours_S = list(map(to_hours, study_points))

# %%
river_hours_C = list(map(to_hours, control_points))
river_hours_C = [i for i in river_hours_C if i<len(values)] #keep values in the initial date range

# %%
fig, axs = plt.subplots(1,1, figsize = (8,7))

labels = ('Other trajectories', 'Southern trajectories')



control_group = [values[i] for i in river_hours_C]
study_group = [values[i] for i in river_hours_S]

groups = [control_group, study_group]

colors = ['b','r']


axs.hist(
        groups, 
        color= colors, 
        alpha=0.8, 
        normed = True,
        label = labels, 
        )

axs.set_ylabel ("Percentage of trajectories")
axs.set_xlabel ("River flow (m$^{3}$/s)")

axs.set_title ('River flow \n June 1 - September 30', size = 18)


plt.legend()

# %%
len(control_group)
# Out:
# 153408

# %%
len(study_group)
# Out:
# 3744

# %%
def load_tidal_predictions(filename):
    """Load tidal prediction from a file.

    :arg str filename: The path and file name of a CSV file that contains
                       ttide tidal predictions generated by
                       :kbd:`get_ttide_8.m`.

    :returns: ttide: Tidal predictions and mean sea level,
                     the mean component from the harmonic analysis.
    :rtype: :py:class:`pandas.DataFrame`
    """
    with open(filename) as f:
        mycsv = list(csv.reader(f))
        msl = float(mycsv[1][1])
    ttide = pd.read_csv(
        filename, skiprows=3, parse_dates=[0], date_parser=dateParserMeasured2)
    ttide = ttide.rename(
        columns={
            'Time_Local ': 'time',
            ' pred_8 ': 'pred_8',
            ' pred_all ': 'pred_all',
        })
    return ttide, msl

# %%
sdt, edt = start, end, 

tdir = '/ocean/gsgarbi/MEOPAR/SalishSeaNowcast/tidal_predictions/'
name = 'Point Atkinson'
fname = os.path.join(tdir, '{}_tidal_prediction_01-Jan-2015_01-Jan-2020.csv'.format(name))
ttide, _ = load_tidal_predictions(fname)
print (ttide.time)
print ('-------------')
print (ttide.pred_all)
# Out:
# 0       2015-01-01 08:00:00+00:00
# 1       2015-01-01 09:00:00+00:00
# 2       2015-01-01 10:00:00+00:00
# 3       2015-01-01 11:00:00+00:00
# 4       2015-01-01 12:00:00+00:00
# 5       2015-01-01 13:00:00+00:00
# 6       2015-01-01 14:00:00+00:00
# 7       2015-01-01 15:00:00+00:00
# 8       2015-01-01 16:00:00+00:00
# 9       2015-01-01 17:00:00+00:00
# 10      2015-01-01 18:00:00+00:00
# 11      2015-01-01 19:00:00+00:00
# 12      2015-01-01 20:00:00+00:00
# 13      2015-01-01 21:00:00+00:00
# 14      2015-01-01 22:00:00+00:00
# 15      2015-01-01 23:00:00+00:00
# 16      2015-01-02 00:00:00+00:00
# 17      2015-01-02 01:00:00+00:00
# 18      2015-01-02 02:00:00+00:00
# 19      2015-01-02 03:00:00+00:00
# 20      2015-01-02 04:00:00+00:00
# 21      2015-01-02 05:00:00+00:00
# 22      2015-01-02 06:00:00+00:00
# 23      2015-01-02 07:00:00+00:00
# 24      2015-01-02 08:00:00+00:00
# 25      2015-01-02 09:00:00+00:00
# 26      2015-01-02 10:00:00+00:00
# 27      2015-01-02 11:00:00+00:00
# 28      2015-01-02 12:00:00+00:00
# 29      2015-01-02 13:00:00+00:00
#                    ...
# 43795   2019-12-31 03:00:00+00:00
# 43796   2019-12-31 04:00:00+00:00
# 43797   2019-12-31 05:00:00+00:00
# 43798   2019-12-31 06:00:00+00:00
# 43799   2019-12-31 07:00:00+00:00
# 43800   2019-12-31 08:00:00+00:00
# 43801   2019-12-31 09:00:00+00:00
# 43802   2019-12-31 10:00:00+00:00
# 43803   2019-12-31 11:00:00+00:00
# 43804   2019-12-31 12:00:00+00:00
# 43805   2019-12-31 13:00:00+00:00
# 43806   2019-12-31 14:00:00+00:00
# 43807   2019-12-31 15:00:00+00:00
# 43808   2019-12-31 16:00:00+00:00
# 43809   2019-12-31 17:00:00+00:00
# 43810   2019-12-31 18:00:00+00:00
# 43811   2019-12-31 19:00:00+00:00
# 43812   2019-12-31 20:00:00+00:00
# 43813   2019-12-31 21:00:00+00:00
# 43814   2019-12-31 22:00:00+00:00
# 43815   2019-12-31 23:00:00+00:00
# 43816   2020-01-01 00:00:00+00:00
# 43817   2020-01-01 01:00:00+00:00
# 43818   2020-01-01 02:00:00+00:00
# 43819   2020-01-01 03:00:00+00:00
# 43820   2020-01-01 04:00:00+00:00
# 43821   2020-01-01 05:00:00+00:00
# 43822   2020-01-01 06:00:00+00:00
# 43823   2020-01-01 07:00:00+00:00
# 43824   2020-01-01 08:00:00+00:00
# Name: time, dtype: datetime64[ns, UTC]
# -------------
# 0       -0.462199
# 1        0.135432
# 2        0.593613
# 3        0.835682
# 4        0.862716
# 5        0.738079
# 6        0.536044
# 7        0.325661
# 8        0.196926
# 9        0.233317
# 10       0.439502
# 11       0.741390
# 12       1.042755
# 13       1.245600
# 14       1.255504
# 15       1.016443
# 16       0.542525
# 17      -0.091535
# 18      -0.792880
# 19      -1.467443
# 20      -1.988006
# 21      -2.210849
# 22      -2.077015
# 23      -1.650076
# 24      -1.036210
# 25      -0.334087
# 26       0.336043
# 27       0.836128
# 28       1.081865
# 29       1.092035
#            ...
# 43795    0.386047
# 43796    0.355484
# 43797    0.150537
# 43798   -0.206986
# 43799   -0.676432
# 43800   -1.184883
# 43801   -1.611761
# 43802   -1.827735
# 43803   -1.756926
# 43804   -1.407179
# 43805   -0.844019
# 43806   -0.153299
# 43807    0.553492
# 43808    1.141023
# 43809    1.505185
# 43810    1.610190
# 43811    1.473158
# 43812    1.152394
# 43813    0.740688
# 43814    0.336886
# 43815    0.021825
# 43816   -0.152518
# 43817   -0.174619
# 43818   -0.077402
# 43819    0.065057
# 43820    0.157145
# 43821    0.130454
# 43822   -0.031281
# 43823   -0.317842
# 43824    0.000000
# Name: pred_all, dtype: float64

# %%
study_points
# Out:
# [datetime.datetime(2016, 7, 1, 0, 0),
#  datetime.datetime(2016, 7, 1, 1, 0),
#  datetime.datetime(2016, 7, 1, 2, 0),
#  datetime.datetime(2016, 7, 1, 3, 0),
#  datetime.datetime(2016, 7, 1, 4, 0),
#  datetime.datetime(2016, 7, 1, 5, 0),
#  datetime.datetime(2016, 7, 1, 6, 0),
#  datetime.datetime(2016, 7, 1, 7, 0),
#  datetime.datetime(2016, 7, 1, 8, 0),
#  datetime.datetime(2016, 7, 1, 9, 0),
#  datetime.datetime(2016, 7, 1, 10, 0),
#  datetime.datetime(2016, 7, 1, 11, 0),
#  datetime.datetime(2016, 7, 1, 12, 0),
#  datetime.datetime(2016, 7, 1, 13, 0),
#  datetime.datetime(2016, 7, 1, 14, 0),
#  datetime.datetime(2016, 7, 1, 15, 0),
#  datetime.datetime(2016, 7, 1, 16, 0),
#  datetime.datetime(2016, 7, 1, 17, 0),
#  datetime.datetime(2016, 7, 1, 18, 0),
#  datetime.datetime(2016, 7, 1, 19, 0),
#  datetime.datetime(2016, 7, 1, 20, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 1, 0, 0),
#  datetime.datetime(2016, 7, 1, 1, 0),
#  datetime.datetime(2016, 7, 1, 2, 0),
#  datetime.datetime(2016, 7, 1, 3, 0),
#  datetime.datetime(2016, 7, 1, 4, 0),
#  datetime.datetime(2016, 7, 1, 5, 0),
#  datetime.datetime(2016, 7, 1, 6, 0),
#  datetime.datetime(2016, 7, 1, 7, 0),
#  datetime.datetime(2016, 7, 1, 8, 0),
#  datetime.datetime(2016, 7, 1, 9, 0),
#  datetime.datetime(2016, 7, 1, 10, 0),
#  datetime.datetime(2016, 7, 1, 11, 0),
#  datetime.datetime(2016, 7, 1, 12, 0),
#  datetime.datetime(2016, 7, 1, 13, 0),
#  datetime.datetime(2016, 7, 1, 14, 0),
#  datetime.datetime(2016, 7, 1, 15, 0),
#  datetime.datetime(2016, 7, 1, 16, 0),
#  datetime.datetime(2016, 7, 1, 17, 0),
#  datetime.datetime(2016, 7, 1, 18, 0),
#  datetime.datetime(2016, 7, 1, 19, 0),
#  datetime.datetime(2016, 7, 1, 20, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 1, 1, 0),
#  datetime.datetime(2016, 7, 1, 2, 0),
#  datetime.datetime(2016, 7, 1, 3, 0),
#  datetime.datetime(2016, 7, 1, 4, 0),
#  datetime.datetime(2016, 7, 1, 5, 0),
#  datetime.datetime(2016, 7, 1, 6, 0),
#  datetime.datetime(2016, 7, 1, 7, 0),
#  datetime.datetime(2016, 7, 1, 8, 0),
#  datetime.datetime(2016, 7, 1, 9, 0),
#  datetime.datetime(2016, 7, 1, 10, 0),
#  datetime.datetime(2016, 7, 1, 11, 0),
#  datetime.datetime(2016, 7, 1, 12, 0),
#  datetime.datetime(2016, 7, 1, 13, 0),
#  datetime.datetime(2016, 7, 1, 14, 0),
#  datetime.datetime(2016, 7, 1, 15, 0),
#  datetime.datetime(2016, 7, 1, 16, 0),
#  datetime.datetime(2016, 7, 1, 17, 0),
#  datetime.datetime(2016, 7, 1, 18, 0),
#  datetime.datetime(2016, 7, 1, 19, 0),
#  datetime.datetime(2016, 7, 1, 20, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 1, 1, 0),
#  datetime.datetime(2016, 7, 1, 2, 0),
#  datetime.datetime(2016, 7, 1, 3, 0),
#  datetime.datetime(2016, 7, 1, 4, 0),
#  datetime.datetime(2016, 7, 1, 5, 0),
#  datetime.datetime(2016, 7, 1, 6, 0),
#  datetime.datetime(2016, 7, 1, 7, 0),
#  datetime.datetime(2016, 7, 1, 8, 0),
#  datetime.datetime(2016, 7, 1, 9, 0),
#  datetime.datetime(2016, 7, 1, 10, 0),
#  datetime.datetime(2016, 7, 1, 11, 0),
#  datetime.datetime(2016, 7, 1, 12, 0),
#  datetime.datetime(2016, 7, 1, 13, 0),
#  datetime.datetime(2016, 7, 1, 14, 0),
#  datetime.datetime(2016, 7, 1, 15, 0),
#  datetime.datetime(2016, 7, 1, 16, 0),
#  datetime.datetime(2016, 7, 1, 17, 0),
#  datetime.datetime(2016, 7, 1, 18, 0),
#  datetime.datetime(2016, 7, 1, 19, 0),
#  datetime.datetime(2016, 7, 1, 20, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 1, 7, 0),
#  datetime.datetime(2016, 7, 1, 8, 0),
#  datetime.datetime(2016, 7, 1, 9, 0),
#  datetime.datetime(2016, 7, 1, 10, 0),
#  datetime.datetime(2016, 7, 1, 11, 0),
#  datetime.datetime(2016, 7, 1, 12, 0),
#  datetime.datetime(2016, 7, 1, 13, 0),
#  datetime.datetime(2016, 7, 1, 14, 0),
#  datetime.datetime(2016, 7, 1, 15, 0),
#  datetime.datetime(2016, 7, 1, 16, 0),
#  datetime.datetime(2016, 7, 1, 17, 0),
#  datetime.datetime(2016, 7, 1, 18, 0),
#  datetime.datetime(2016, 7, 1, 19, 0),
#  datetime.datetime(2016, 7, 1, 20, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 2, 1, 0),
#  datetime.datetime(2016, 7, 2, 2, 0),
#  datetime.datetime(2016, 7, 2, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 1, 8, 0),
#  datetime.datetime(2016, 7, 1, 9, 0),
#  datetime.datetime(2016, 7, 1, 10, 0),
#  datetime.datetime(2016, 7, 1, 11, 0),
#  datetime.datetime(2016, 7, 1, 12, 0),
#  datetime.datetime(2016, 7, 1, 13, 0),
#  datetime.datetime(2016, 7, 1, 14, 0),
#  datetime.datetime(2016, 7, 1, 15, 0),
#  datetime.datetime(2016, 7, 1, 16, 0),
#  datetime.datetime(2016, 7, 1, 17, 0),
#  datetime.datetime(2016, 7, 1, 18, 0),
#  datetime.datetime(2016, 7, 1, 19, 0),
#  datetime.datetime(2016, 7, 1, 20, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 2, 1, 0),
#  datetime.datetime(2016, 7, 2, 2, 0),
#  datetime.datetime(2016, 7, 2, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 1, 19, 0),
#  datetime.datetime(2016, 7, 1, 20, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 2, 1, 0),
#  datetime.datetime(2016, 7, 2, 2, 0),
#  datetime.datetime(2016, 7, 2, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 1, 20, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 2, 1, 0),
#  datetime.datetime(2016, 7, 2, 2, 0),
#  datetime.datetime(2016, 7, 2, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 2, 1, 0),
#  datetime.datetime(2016, 7, 2, 2, 0),
#  datetime.datetime(2016, 7, 2, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 1, 21, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 2, 1, 0),
#  datetime.datetime(2016, 7, 2, 2, 0),
#  datetime.datetime(2016, 7, 2, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 1, 22, 0),
#  datetime.datetime(2016, 7, 1, 23, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 2, 1, 0),
#  datetime.datetime(2016, 7, 2, 2, 0),
#  datetime.datetime(2016, 7, 2, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 2, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 2, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 2, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 2, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 2, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 3, 8, 0),
#  datetime.datetime(2016, 7, 2, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 3, 8, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 3, 8, 0),
#  datetime.datetime(2016, 7, 3, 9, 0),
#  datetime.datetime(2016, 7, 2, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 3, 8, 0),
#  datetime.datetime(2016, 7, 3, 9, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 3, 8, 0),
#  datetime.datetime(2016, 7, 3, 9, 0),
#  datetime.datetime(2016, 7, 3, 10, 0),
#  datetime.datetime(2016, 7, 2, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 3, 8, 0),
#  datetime.datetime(2016, 7, 3, 9, 0),
#  datetime.datetime(2016, 7, 3, 10, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 3, 8, 0),
#  datetime.datetime(2016, 7, 3, 9, 0),
#  datetime.datetime(2016, 7, 3, 10, 0),
#  datetime.datetime(2016, 7, 3, 11, 0),
#  datetime.datetime(2016, 7, 2, 12, 0),
#  datetime.datetime(2016, 7, 2, 13, 0),
#  datetime.datetime(2016, 7, 2, 14, 0),
#  datetime.datetime(2016, 7, 2, 15, 0),
#  datetime.datetime(2016, 7, 2, 16, 0),
#  datetime.datetime(2016, 7, 2, 17, 0),
#  datetime.datetime(2016, 7, 2, 18, 0),
#  datetime.datetime(2016, 7, 2, 19, 0),
#  datetime.datetime(2016, 7, 2, 20, 0),
#  datetime.datetime(2016, 7, 2, 21, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 3, 8, 0),
#  datetime.datetime(2016, 7, 3, 9, 0),
#  datetime.datetime(2016, 7, 3, 10, 0),
#  datetime.datetime(2016, 7, 3, 11, 0),
#  datetime.datetime(2016, 7, 2, 22, 0),
#  datetime.datetime(2016, 7, 2, 23, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 3, 1, 0),
#  datetime.datetime(2016, 7, 3, 2, 0),
#  datetime.datetime(2016, 7, 3, 3, 0),
#  datetime.datetime(2016, 7, 3, 4, 0),
#  datetime.datetime(2016, 7, 3, 5, 0),
#  datetime.datetime(2016, 7, 3, 6, 0),
#  datetime.datetime(2016, 7, 3, 7, 0),
#  datetime.datetime(2016, 7, 3, 8, 0),
#  datetime.datetime(2016, 7, 3, 9, 0),
#  datetime.datetime(2016, 7, 3, 10, 0),
#  datetime.datetime(2016, 7, 3, 11, 0),
#  datetime.datetime(2016, 7, 3, 12, 0),
#  datetime.datetime(2016, 7, 3, 13, 0),
#  datetime.datetime(2016, 7, 3, 14, 0),
#  datetime.datetime(2016, 7, 3, 15, 0),
#  datetime.datetime(2016, 7, 3, 16, 0),
#  datetime.datetime(2016, 7, 3, 17, 0),
#  datetime.datetime(2016, 7, 3, 18, 0),
#  datetime.datetime(2016, 7, 3, 19, 0),
#  datetime.datetime(2016, 7, 3, 20, 0),
#  datetime.datetime(2016, 7, 3, 21, 0),
#  datetime.datetime(2016, 7, 7, 14, 0),
#  datetime.datetime(2016, 7, 7, 15, 0),
#  datetime.datetime(2016, 7, 7, 16, 0),
#  datetime.datetime(2016, 7, 7, 17, 0),
#  datetime.datetime(2016, 7, 7, 18, 0),
#  datetime.datetime(2016, 7, 7, 19, 0),
#  datetime.datetime(2016, 7, 7, 20, 0),
#  datetime.datetime(2016, 7, 7, 21, 0),
#  datetime.datetime(2016, 7, 7, 22, 0),
#  datetime.datetime(2016, 7, 7, 23, 0),
#  datetime.datetime(2016, 7, 8, 0, 0),
#  datetime.datetime(2016, 7, 8, 1, 0),
#  datetime.datetime(2016, 7, 8, 2, 0),
#  datetime.datetime(2016, 7, 8, 3, 0),
#  datetime.datetime(2016, 7, 8, 4, 0),
#  datetime.datetime(2016, 7, 8, 5, 0),
#  datetime.datetime(2016, 7, 8, 6, 0),
#  datetime.datetime(2016, 7, 8, 7, 0),
#  datetime.datetime(2016, 7, 8, 8, 0),
#  datetime.datetime(2016, 7, 8, 9, 0),
#  datetime.datetime(2016, 7, 8, 10, 0),
#  datetime.datetime(2016, 7, 8, 11, 0),
#  datetime.datetime(2016, 7, 8, 12, 0),
#  datetime.datetime(2016, 7, 8, 13, 0),
#  datetime.datetime(2016, 7, 7, 15, 0),
#  datetime.datetime(2016, 7, 7, 16, 0),
#  datetime.datetime(2016, 7, 7, 17, 0),
#  datetime.datetime(2016, 7, 7, 18, 0),
#  datetime.datetime(2016, 7, 7, 19, 0),
#  datetime.datetime(2016, 7, 7, 20, 0),
#  datetime.datetime(2016, 7, 7, 21, 0),
#  datetime.datetime(2016, 7, 7, 22, 0),
#  datetime.datetime(2016, 7, 7, 23, 0),
#  datetime.datetime(2016, 7, 8, 0, 0),
#  datetime.datetime(2016, 7, 8, 1, 0),
#  datetime.datetime(2016, 7, 8, 2, 0),
#  datetime.datetime(2016, 7, 8, 3, 0),
#  datetime.datetime(2016, 7, 8, 4, 0),
#  datetime.datetime(2016, 7, 8, 5, 0),
#  datetime.datetime(2016, 7, 8, 6, 0),
#  datetime.datetime(2016, 7, 8, 7, 0),
#  datetime.datetime(2016, 7, 8, 8, 0),
#  datetime.datetime(2016, 7, 8, 9, 0),
#  datetime.datetime(2016, 7, 8, 10, 0),
#  datetime.datetime(2016, 7, 8, 11, 0),
#  datetime.datetime(2016, 7, 8, 12, 0),
#  datetime.datetime(2016, 7, 8, 13, 0),
#  datetime.datetime(2016, 7, 8, 14, 0),
#  datetime.datetime(2016, 7, 12, 22, 0),
#  datetime.datetime(2016, 7, 12, 23, 0),
#  datetime.datetime(2016, 7, 13, 0, 0),
#  datetime.datetime(2016, 7, 13, 1, 0),
#  datetime.datetime(2016, 7, 13, 2, 0),
#  datetime.datetime(2016, 7, 13, 3, 0),
#  datetime.datetime(2016, 7, 13, 4, 0),
#  datetime.datetime(2016, 7, 13, 5, 0),
#  datetime.datetime(2016, 7, 13, 6, 0),
#  datetime.datetime(2016, 7, 13, 7, 0),
#  datetime.datetime(2016, 7, 13, 8, 0),
#  datetime.datetime(2016, 7, 13, 9, 0),
#  datetime.datetime(2016, 7, 13, 10, 0),
#  datetime.datetime(2016, 7, 13, 11, 0),
#  datetime.datetime(2016, 7, 13, 12, 0),
#  datetime.datetime(2016, 7, 13, 13, 0),
#  datetime.datetime(2016, 7, 13, 14, 0),
#  datetime.datetime(2016, 7, 13, 15, 0),
#  datetime.datetime(2016, 7, 13, 16, 0),
#  datetime.datetime(2016, 7, 13, 17, 0),
#  datetime.datetime(2016, 7, 13, 18, 0),
#  datetime.datetime(2016, 7, 13, 19, 0),
#  datetime.datetime(2016, 7, 13, 20, 0),
#  datetime.datetime(2016, 7, 13, 21, 0),
#  datetime.datetime(2016, 7, 12, 23, 0),
#  datetime.datetime(2016, 7, 13, 0, 0),
#  datetime.datetime(2016, 7, 13, 1, 0),
#  datetime.datetime(2016, 7, 13, 2, 0),
#  datetime.datetime(2016, 7, 13, 3, 0),
#  datetime.datetime(2016, 7, 13, 4, 0),
#  datetime.datetime(2016, 7, 13, 5, 0),
#  datetime.datetime(2016, 7, 13, 6, 0),
#  datetime.datetime(2016, 7, 13, 7, 0),
#  datetime.datetime(2016, 7, 13, 8, 0),
#  datetime.datetime(2016, 7, 13, 9, 0),
#  datetime.datetime(2016, 7, 13, 10, 0),
#  datetime.datetime(2016, 7, 13, 11, 0),
#  datetime.datetime(2016, 7, 13, 12, 0),
#  datetime.datetime(2016, 7, 13, 13, 0),
#  datetime.datetime(2016, 7, 13, 14, 0),
#  datetime.datetime(2016, 7, 13, 15, 0),
#  datetime.datetime(2016, 7, 13, 16, 0),
#  datetime.datetime(2016, 7, 13, 17, 0),
#  datetime.datetime(2016, 7, 13, 18, 0),
#  datetime.datetime(2016, 7, 13, 19, 0),
#  datetime.datetime(2016, 7, 13, 20, 0),
#  datetime.datetime(2016, 7, 13, 21, 0),
#  datetime.datetime(2016, 7, 13, 22, 0),
#  datetime.datetime(2016, 7, 15, 19, 0),
#  datetime.datetime(2016, 7, 15, 20, 0),
#  datetime.datetime(2016, 7, 15, 21, 0),
#  datetime.datetime(2016, 7, 15, 22, 0),
#  datetime.datetime(2016, 7, 15, 23, 0),
#  datetime.datetime(2016, 7, 16, 0, 0),
#  datetime.datetime(2016, 7, 16, 1, 0),
#  datetime.datetime(2016, 7, 16, 2, 0),
#  datetime.datetime(2016, 7, 16, 3, 0),
#  datetime.datetime(2016, 7, 16, 4, 0),
#  datetime.datetime(2016, 7, 16, 5, 0),
#  datetime.datetime(2016, 7, 16, 6, 0),
#  datetime.datetime(2016, 7, 16, 7, 0),
#  datetime.datetime(2016, 7, 16, 8, 0),
#  datetime.datetime(2016, 7, 16, 9, 0),
#  datetime.datetime(2016, 7, 16, 10, 0),
#  datetime.datetime(2016, 7, 16, 11, 0),
#  datetime.datetime(2016, 7, 16, 12, 0),
#  datetime.datetime(2016, 7, 16, 13, 0),
#  datetime.datetime(2016, 7, 16, 14, 0),
#  datetime.datetime(2016, 7, 16, 15, 0),
#  datetime.datetime(2016, 7, 16, 16, 0),
#  datetime.datetime(2016, 7, 16, 17, 0),
#  datetime.datetime(2016, 7, 16, 18, 0),
#  datetime.datetime(2016, 7, 16, 0, 0),
#  datetime.datetime(2016, 7, 16, 1, 0),
#  datetime.datetime(2016, 7, 16, 2, 0),
#  datetime.datetime(2016, 7, 16, 3, 0),
#  datetime.datetime(2016, 7, 16, 4, 0),
#  datetime.datetime(2016, 7, 16, 5, 0),
#  datetime.datetime(2016, 7, 16, 6, 0),
#  datetime.datetime(2016, 7, 16, 7, 0),
#  datetime.datetime(2016, 7, 16, 8, 0),
#  datetime.datetime(2016, 7, 16, 9, 0),
#  datetime.datetime(2016, 7, 16, 10, 0),
#  datetime.datetime(2016, 7, 16, 11, 0),
#  datetime.datetime(2016, 7, 16, 12, 0),
#  datetime.datetime(2016, 7, 16, 13, 0),
#  datetime.datetime(2016, 7, 16, 14, 0),
#  datetime.datetime(2016, 7, 16, 15, 0),
#  datetime.datetime(2016, 7, 16, 16, 0),
#  datetime.datetime(2016, 7, 16, 17, 0),
#  datetime.datetime(2016, 7, 16, 18, 0),
#  datetime.datetime(2016, 7, 16, 19, 0),
#  datetime.datetime(2016, 7, 16, 20, 0),
#  datetime.datetime(2016, 7, 16, 21, 0),
#  datetime.datetime(2016, 7, 16, 22, 0),
#  datetime.datetime(2016, 7, 16, 23, 0),
#  datetime.datetime(2016, 7, 16, 20, 0),
#  datetime.datetime(2016, 7, 16, 21, 0),
#  datetime.datetime(2016, 7, 16, 22, 0),
#  datetime.datetime(2016, 7, 16, 23, 0),
#  datetime.datetime(2016, 7, 17, 0, 0),
#  datetime.datetime(2016, 7, 17, 1, 0),
#  datetime.datetime(2016, 7, 17, 2, 0),
#  datetime.datetime(2016, 7, 17, 3, 0),
#  datetime.datetime(2016, 7, 17, 4, 0),
#  datetime.datetime(2016, 7, 17, 5, 0),
#  datetime.datetime(2016, 7, 17, 6, 0),
#  datetime.datetime(2016, 7, 17, 7, 0),
#  datetime.datetime(2016, 7, 17, 8, 0),
#  datetime.datetime(2016, 7, 17, 9, 0),
#  datetime.datetime(2016, 7, 17, 10, 0),
#  datetime.datetime(2016, 7, 17, 11, 0),
#  datetime.datetime(2016, 7, 17, 12, 0),
#  datetime.datetime(2016, 7, 17, 13, 0),
#  datetime.datetime(2016, 7, 17, 14, 0),
#  datetime.datetime(2016, 7, 17, 15, 0),
#  datetime.datetime(2016, 7, 17, 16, 0),
#  datetime.datetime(2016, 7, 17, 17, 0),
#  datetime.datetime(2016, 7, 17, 18, 0),
#  datetime.datetime(2016, 7, 17, 19, 0),
#  datetime.datetime(2016, 7, 17, 2, 0),
#  datetime.datetime(2016, 7, 17, 3, 0),
#  datetime.datetime(2016, 7, 17, 4, 0),
#  datetime.datetime(2016, 7, 17, 5, 0),
#  datetime.datetime(2016, 7, 17, 6, 0),
#  datetime.datetime(2016, 7, 17, 7, 0),
#  datetime.datetime(2016, 7, 17, 8, 0),
#  datetime.datetime(2016, 7, 17, 9, 0),
#  datetime.datetime(2016, 7, 17, 10, 0),
#  datetime.datetime(2016, 7, 17, 11, 0),
#  datetime.datetime(2016, 7, 17, 12, 0),
#  datetime.datetime(2016, 7, 17, 13, 0),
#  datetime.datetime(2016, 7, 17, 14, 0),
#  datetime.datetime(2016, 7, 17, 15, 0),
#  datetime.datetime(2016, 7, 17, 16, 0),
#  datetime.datetime(2016, 7, 17, 17, 0),
#  datetime.datetime(2016, 7, 17, 18, 0),
#  datetime.datetime(2016, 7, 17, 19, 0),
#  datetime.datetime(2016, 7, 17, 20, 0),
#  datetime.datetime(2016, 7, 17, 21, 0),
#  datetime.datetime(2016, 7, 17, 22, 0),
#  datetime.datetime(2016, 7, 17, 23, 0),
#  datetime.datetime(2016, 7, 18, 0, 0),
#  datetime.datetime(2016, 7, 18, 1, 0),
#  datetime.datetime(2016, 7, 17, 4, 0),
#  datetime.datetime(2016, 7, 17, 5, 0),
#  datetime.datetime(2016, 7, 17, 6, 0),
#  datetime.datetime(2016, 7, 17, 7, 0),
#  datetime.datetime(2016, 7, 17, 8, 0),
#  datetime.datetime(2016, 7, 17, 9, 0),
#  datetime.datetime(2016, 7, 17, 10, 0),
#  datetime.datetime(2016, 7, 17, 11, 0),
#  datetime.datetime(2016, 7, 17, 12, 0),
#  datetime.datetime(2016, 7, 17, 13, 0),
#  datetime.datetime(2016, 7, 17, 14, 0),
#  datetime.datetime(2016, 7, 17, 15, 0),
#  datetime.datetime(2016, 7, 17, 16, 0),
#  datetime.datetime(2016, 7, 17, 17, 0),
#  datetime.datetime(2016, 7, 17, 18, 0),
#  datetime.datetime(2016, 7, 17, 19, 0),
#  ...]

# %%
def to_dt (date):
    y = date.year
    m = date.month
    d = date.day
    h = date.hour
    mins = 0
    return dt.datetime(y,m,d, h, mins)

# %%
ftimes = list(map(to_dt, ttide.time)) 
fpreds = list(ttide.pred_all)

# %%
def tide_analysis (date, times = ftimes, preds = fpreds):
    index = times.index(date)
    l = index - 13
    L = index + 13
    M = max(preds[l:L+1])
    m = min(preds[l:L+1])
    A = M - m
    MM = max (preds[index - 25 : index])
    Mindex = preds.index(MM)
    phi = index - Mindex
    return M, m, A, phi

# %%
def plot_tanalysis(cts, sts, i, normed = True):
    
    fig, axs = plt.subplots(1,1, figsize = (30,20))

    fig.suptitle('Tidal analysis for \n June 1 - September 30', size = 60)

    labels = ('Other trajectories', 'Southern trajectories')
    colors = ['b','r']

    titles = ['Maxs(m)', 'Mins(m)', 'Amplitudes(m)', 'Phase (h)']
    sts = [st_Ms, st_ms, st_As, st_phis]
    cts = [ct_Ms, ct_ms, ct_As, ct_phis]

    axs.tick_params(labelsize = 30,)

    control_group = cts[i]
    study_group = sts[i]

    groups = [control_group, study_group]


    axs.hist(
            groups, 
            color= colors, 
            alpha=0.8, 
            normed = normed,
            label = labels, 
            )
    
    plt.legend(loc = 0, fontsize = '30')
    
    axs.set_ylabel ("Percentage of trajectories", size = 30)
    axs.set_xlabel (titles[i], size = 40)

# %%
ftimes
# Out:
# [datetime.datetime(2015, 1, 1, 8, 0),
#  datetime.datetime(2015, 1, 1, 9, 0),
#  datetime.datetime(2015, 1, 1, 10, 0),
#  datetime.datetime(2015, 1, 1, 11, 0),
#  datetime.datetime(2015, 1, 1, 12, 0),
#  datetime.datetime(2015, 1, 1, 13, 0),
#  datetime.datetime(2015, 1, 1, 14, 0),
#  datetime.datetime(2015, 1, 1, 15, 0),
#  datetime.datetime(2015, 1, 1, 16, 0),
#  datetime.datetime(2015, 1, 1, 17, 0),
#  datetime.datetime(2015, 1, 1, 18, 0),
#  datetime.datetime(2015, 1, 1, 19, 0),
#  datetime.datetime(2015, 1, 1, 20, 0),
#  datetime.datetime(2015, 1, 1, 21, 0),
#  datetime.datetime(2015, 1, 1, 22, 0),
#  datetime.datetime(2015, 1, 1, 23, 0),
#  datetime.datetime(2015, 1, 2, 0, 0),
#  datetime.datetime(2015, 1, 2, 1, 0),
#  datetime.datetime(2015, 1, 2, 2, 0),
#  datetime.datetime(2015, 1, 2, 3, 0),
#  datetime.datetime(2015, 1, 2, 4, 0),
#  datetime.datetime(2015, 1, 2, 5, 0),
#  datetime.datetime(2015, 1, 2, 6, 0),
#  datetime.datetime(2015, 1, 2, 7, 0),
#  datetime.datetime(2015, 1, 2, 8, 0),
#  datetime.datetime(2015, 1, 2, 9, 0),
#  datetime.datetime(2015, 1, 2, 10, 0),
#  datetime.datetime(2015, 1, 2, 11, 0),
#  datetime.datetime(2015, 1, 2, 12, 0),
#  datetime.datetime(2015, 1, 2, 13, 0),
#  datetime.datetime(2015, 1, 2, 14, 0),
#  datetime.datetime(2015, 1, 2, 15, 0),
#  datetime.datetime(2015, 1, 2, 16, 0),
#  datetime.datetime(2015, 1, 2, 17, 0),
#  datetime.datetime(2015, 1, 2, 18, 0),
#  datetime.datetime(2015, 1, 2, 19, 0),
#  datetime.datetime(2015, 1, 2, 20, 0),
#  datetime.datetime(2015, 1, 2, 21, 0),
#  datetime.datetime(2015, 1, 2, 22, 0),
#  datetime.datetime(2015, 1, 2, 23, 0),
#  datetime.datetime(2015, 1, 3, 0, 0),
#  datetime.datetime(2015, 1, 3, 1, 0),
#  datetime.datetime(2015, 1, 3, 2, 0),
#  datetime.datetime(2015, 1, 3, 3, 0),
#  datetime.datetime(2015, 1, 3, 4, 0),
#  datetime.datetime(2015, 1, 3, 5, 0),
#  datetime.datetime(2015, 1, 3, 6, 0),
#  datetime.datetime(2015, 1, 3, 7, 0),
#  datetime.datetime(2015, 1, 3, 8, 0),
#  datetime.datetime(2015, 1, 3, 9, 0),
#  datetime.datetime(2015, 1, 3, 10, 0),
#  datetime.datetime(2015, 1, 3, 11, 0),
#  datetime.datetime(2015, 1, 3, 12, 0),
#  datetime.datetime(2015, 1, 3, 13, 0),
#  datetime.datetime(2015, 1, 3, 14, 0),
#  datetime.datetime(2015, 1, 3, 15, 0),
#  datetime.datetime(2015, 1, 3, 16, 0),
#  datetime.datetime(2015, 1, 3, 17, 0),
#  datetime.datetime(2015, 1, 3, 18, 0),
#  datetime.datetime(2015, 1, 3, 19, 0),
#  datetime.datetime(2015, 1, 3, 20, 0),
#  datetime.datetime(2015, 1, 3, 21, 0),
#  datetime.datetime(2015, 1, 3, 22, 0),
#  datetime.datetime(2015, 1, 3, 23, 0),
#  datetime.datetime(2015, 1, 4, 0, 0),
#  datetime.datetime(2015, 1, 4, 1, 0),
#  datetime.datetime(2015, 1, 4, 2, 0),
#  datetime.datetime(2015, 1, 4, 3, 0),
#  datetime.datetime(2015, 1, 4, 4, 0),
#  datetime.datetime(2015, 1, 4, 5, 0),
#  datetime.datetime(2015, 1, 4, 6, 0),
#  datetime.datetime(2015, 1, 4, 7, 0),
#  datetime.datetime(2015, 1, 4, 8, 0),
#  datetime.datetime(2015, 1, 4, 9, 0),
#  datetime.datetime(2015, 1, 4, 10, 0),
#  datetime.datetime(2015, 1, 4, 11, 0),
#  datetime.datetime(2015, 1, 4, 12, 0),
#  datetime.datetime(2015, 1, 4, 13, 0),
#  datetime.datetime(2015, 1, 4, 14, 0),
#  datetime.datetime(2015, 1, 4, 15, 0),
#  datetime.datetime(2015, 1, 4, 16, 0),
#  datetime.datetime(2015, 1, 4, 17, 0),
#  datetime.datetime(2015, 1, 4, 18, 0),
#  datetime.datetime(2015, 1, 4, 19, 0),
#  datetime.datetime(2015, 1, 4, 20, 0),
#  datetime.datetime(2015, 1, 4, 21, 0),
#  datetime.datetime(2015, 1, 4, 22, 0),
#  datetime.datetime(2015, 1, 4, 23, 0),
#  datetime.datetime(2015, 1, 5, 0, 0),
#  datetime.datetime(2015, 1, 5, 1, 0),
#  datetime.datetime(2015, 1, 5, 2, 0),
#  datetime.datetime(2015, 1, 5, 3, 0),
#  datetime.datetime(2015, 1, 5, 4, 0),
#  datetime.datetime(2015, 1, 5, 5, 0),
#  datetime.datetime(2015, 1, 5, 6, 0),
#  datetime.datetime(2015, 1, 5, 7, 0),
#  datetime.datetime(2015, 1, 5, 8, 0),
#  datetime.datetime(2015, 1, 5, 9, 0),
#  datetime.datetime(2015, 1, 5, 10, 0),
#  datetime.datetime(2015, 1, 5, 11, 0),
#  datetime.datetime(2015, 1, 5, 12, 0),
#  datetime.datetime(2015, 1, 5, 13, 0),
#  datetime.datetime(2015, 1, 5, 14, 0),
#  datetime.datetime(2015, 1, 5, 15, 0),
#  datetime.datetime(2015, 1, 5, 16, 0),
#  datetime.datetime(2015, 1, 5, 17, 0),
#  datetime.datetime(2015, 1, 5, 18, 0),
#  datetime.datetime(2015, 1, 5, 19, 0),
#  datetime.datetime(2015, 1, 5, 20, 0),
#  datetime.datetime(2015, 1, 5, 21, 0),
#  datetime.datetime(2015, 1, 5, 22, 0),
#  datetime.datetime(2015, 1, 5, 23, 0),
#  datetime.datetime(2015, 1, 6, 0, 0),
#  datetime.datetime(2015, 1, 6, 1, 0),
#  datetime.datetime(2015, 1, 6, 2, 0),
#  datetime.datetime(2015, 1, 6, 3, 0),
#  datetime.datetime(2015, 1, 6, 4, 0),
#  datetime.datetime(2015, 1, 6, 5, 0),
#  datetime.datetime(2015, 1, 6, 6, 0),
#  datetime.datetime(2015, 1, 6, 7, 0),
#  datetime.datetime(2015, 1, 6, 8, 0),
#  datetime.datetime(2015, 1, 6, 9, 0),
#  datetime.datetime(2015, 1, 6, 10, 0),
#  datetime.datetime(2015, 1, 6, 11, 0),
#  datetime.datetime(2015, 1, 6, 12, 0),
#  datetime.datetime(2015, 1, 6, 13, 0),
#  datetime.datetime(2015, 1, 6, 14, 0),
#  datetime.datetime(2015, 1, 6, 15, 0),
#  datetime.datetime(2015, 1, 6, 16, 0),
#  datetime.datetime(2015, 1, 6, 17, 0),
#  datetime.datetime(2015, 1, 6, 18, 0),
#  datetime.datetime(2015, 1, 6, 19, 0),
#  datetime.datetime(2015, 1, 6, 20, 0),
#  datetime.datetime(2015, 1, 6, 21, 0),
#  datetime.datetime(2015, 1, 6, 22, 0),
#  datetime.datetime(2015, 1, 6, 23, 0),
#  datetime.datetime(2015, 1, 7, 0, 0),
#  datetime.datetime(2015, 1, 7, 1, 0),
#  datetime.datetime(2015, 1, 7, 2, 0),
#  datetime.datetime(2015, 1, 7, 3, 0),
#  datetime.datetime(2015, 1, 7, 4, 0),
#  datetime.datetime(2015, 1, 7, 5, 0),
#  datetime.datetime(2015, 1, 7, 6, 0),
#  datetime.datetime(2015, 1, 7, 7, 0),
#  datetime.datetime(2015, 1, 7, 8, 0),
#  datetime.datetime(2015, 1, 7, 9, 0),
#  datetime.datetime(2015, 1, 7, 10, 0),
#  datetime.datetime(2015, 1, 7, 11, 0),
#  datetime.datetime(2015, 1, 7, 12, 0),
#  datetime.datetime(2015, 1, 7, 13, 0),
#  datetime.datetime(2015, 1, 7, 14, 0),
#  datetime.datetime(2015, 1, 7, 15, 0),
#  datetime.datetime(2015, 1, 7, 16, 0),
#  datetime.datetime(2015, 1, 7, 17, 0),
#  datetime.datetime(2015, 1, 7, 18, 0),
#  datetime.datetime(2015, 1, 7, 19, 0),
#  datetime.datetime(2015, 1, 7, 20, 0),
#  datetime.datetime(2015, 1, 7, 21, 0),
#  datetime.datetime(2015, 1, 7, 22, 0),
#  datetime.datetime(2015, 1, 7, 23, 0),
#  datetime.datetime(2015, 1, 8, 0, 0),
#  datetime.datetime(2015, 1, 8, 1, 0),
#  datetime.datetime(2015, 1, 8, 2, 0),
#  datetime.datetime(2015, 1, 8, 3, 0),
#  datetime.datetime(2015, 1, 8, 4, 0),
#  datetime.datetime(2015, 1, 8, 5, 0),
#  datetime.datetime(2015, 1, 8, 6, 0),
#  datetime.datetime(2015, 1, 8, 7, 0),
#  datetime.datetime(2015, 1, 8, 8, 0),
#  datetime.datetime(2015, 1, 8, 9, 0),
#  datetime.datetime(2015, 1, 8, 10, 0),
#  datetime.datetime(2015, 1, 8, 11, 0),
#  datetime.datetime(2015, 1, 8, 12, 0),
#  datetime.datetime(2015, 1, 8, 13, 0),
#  datetime.datetime(2015, 1, 8, 14, 0),
#  datetime.datetime(2015, 1, 8, 15, 0),
#  datetime.datetime(2015, 1, 8, 16, 0),
#  datetime.datetime(2015, 1, 8, 17, 0),
#  datetime.datetime(2015, 1, 8, 18, 0),
#  datetime.datetime(2015, 1, 8, 19, 0),
#  datetime.datetime(2015, 1, 8, 20, 0),
#  datetime.datetime(2015, 1, 8, 21, 0),
#  datetime.datetime(2015, 1, 8, 22, 0),
#  datetime.datetime(2015, 1, 8, 23, 0),
#  datetime.datetime(2015, 1, 9, 0, 0),
#  datetime.datetime(2015, 1, 9, 1, 0),
#  datetime.datetime(2015, 1, 9, 2, 0),
#  datetime.datetime(2015, 1, 9, 3, 0),
#  datetime.datetime(2015, 1, 9, 4, 0),
#  datetime.datetime(2015, 1, 9, 5, 0),
#  datetime.datetime(2015, 1, 9, 6, 0),
#  datetime.datetime(2015, 1, 9, 7, 0),
#  datetime.datetime(2015, 1, 9, 8, 0),
#  datetime.datetime(2015, 1, 9, 9, 0),
#  datetime.datetime(2015, 1, 9, 10, 0),
#  datetime.datetime(2015, 1, 9, 11, 0),
#  datetime.datetime(2015, 1, 9, 12, 0),
#  datetime.datetime(2015, 1, 9, 13, 0),
#  datetime.datetime(2015, 1, 9, 14, 0),
#  datetime.datetime(2015, 1, 9, 15, 0),
#  datetime.datetime(2015, 1, 9, 16, 0),
#  datetime.datetime(2015, 1, 9, 17, 0),
#  datetime.datetime(2015, 1, 9, 18, 0),
#  datetime.datetime(2015, 1, 9, 19, 0),
#  datetime.datetime(2015, 1, 9, 20, 0),
#  datetime.datetime(2015, 1, 9, 21, 0),
#  datetime.datetime(2015, 1, 9, 22, 0),
#  datetime.datetime(2015, 1, 9, 23, 0),
#  datetime.datetime(2015, 1, 10, 0, 0),
#  datetime.datetime(2015, 1, 10, 1, 0),
#  datetime.datetime(2015, 1, 10, 2, 0),
#  datetime.datetime(2015, 1, 10, 3, 0),
#  datetime.datetime(2015, 1, 10, 4, 0),
#  datetime.datetime(2015, 1, 10, 5, 0),
#  datetime.datetime(2015, 1, 10, 6, 0),
#  datetime.datetime(2015, 1, 10, 7, 0),
#  datetime.datetime(2015, 1, 10, 8, 0),
#  datetime.datetime(2015, 1, 10, 9, 0),
#  datetime.datetime(2015, 1, 10, 10, 0),
#  datetime.datetime(2015, 1, 10, 11, 0),
#  datetime.datetime(2015, 1, 10, 12, 0),
#  datetime.datetime(2015, 1, 10, 13, 0),
#  datetime.datetime(2015, 1, 10, 14, 0),
#  datetime.datetime(2015, 1, 10, 15, 0),
#  datetime.datetime(2015, 1, 10, 16, 0),
#  datetime.datetime(2015, 1, 10, 17, 0),
#  datetime.datetime(2015, 1, 10, 18, 0),
#  datetime.datetime(2015, 1, 10, 19, 0),
#  datetime.datetime(2015, 1, 10, 20, 0),
#  datetime.datetime(2015, 1, 10, 21, 0),
#  datetime.datetime(2015, 1, 10, 22, 0),
#  datetime.datetime(2015, 1, 10, 23, 0),
#  datetime.datetime(2015, 1, 11, 0, 0),
#  datetime.datetime(2015, 1, 11, 1, 0),
#  datetime.datetime(2015, 1, 11, 2, 0),
#  datetime.datetime(2015, 1, 11, 3, 0),
#  datetime.datetime(2015, 1, 11, 4, 0),
#  datetime.datetime(2015, 1, 11, 5, 0),
#  datetime.datetime(2015, 1, 11, 6, 0),
#  datetime.datetime(2015, 1, 11, 7, 0),
#  datetime.datetime(2015, 1, 11, 8, 0),
#  datetime.datetime(2015, 1, 11, 9, 0),
#  datetime.datetime(2015, 1, 11, 10, 0),
#  datetime.datetime(2015, 1, 11, 11, 0),
#  datetime.datetime(2015, 1, 11, 12, 0),
#  datetime.datetime(2015, 1, 11, 13, 0),
#  datetime.datetime(2015, 1, 11, 14, 0),
#  datetime.datetime(2015, 1, 11, 15, 0),
#  datetime.datetime(2015, 1, 11, 16, 0),
#  datetime.datetime(2015, 1, 11, 17, 0),
#  datetime.datetime(2015, 1, 11, 18, 0),
#  datetime.datetime(2015, 1, 11, 19, 0),
#  datetime.datetime(2015, 1, 11, 20, 0),
#  datetime.datetime(2015, 1, 11, 21, 0),
#  datetime.datetime(2015, 1, 11, 22, 0),
#  datetime.datetime(2015, 1, 11, 23, 0),
#  datetime.datetime(2015, 1, 12, 0, 0),
#  datetime.datetime(2015, 1, 12, 1, 0),
#  datetime.datetime(2015, 1, 12, 2, 0),
#  datetime.datetime(2015, 1, 12, 3, 0),
#  datetime.datetime(2015, 1, 12, 4, 0),
#  datetime.datetime(2015, 1, 12, 5, 0),
#  datetime.datetime(2015, 1, 12, 6, 0),
#  datetime.datetime(2015, 1, 12, 7, 0),
#  datetime.datetime(2015, 1, 12, 8, 0),
#  datetime.datetime(2015, 1, 12, 9, 0),
#  datetime.datetime(2015, 1, 12, 10, 0),
#  datetime.datetime(2015, 1, 12, 11, 0),
#  datetime.datetime(2015, 1, 12, 12, 0),
#  datetime.datetime(2015, 1, 12, 13, 0),
#  datetime.datetime(2015, 1, 12, 14, 0),
#  datetime.datetime(2015, 1, 12, 15, 0),
#  datetime.datetime(2015, 1, 12, 16, 0),
#  datetime.datetime(2015, 1, 12, 17, 0),
#  datetime.datetime(2015, 1, 12, 18, 0),
#  datetime.datetime(2015, 1, 12, 19, 0),
#  datetime.datetime(2015, 1, 12, 20, 0),
#  datetime.datetime(2015, 1, 12, 21, 0),
#  datetime.datetime(2015, 1, 12, 22, 0),
#  datetime.datetime(2015, 1, 12, 23, 0),
#  datetime.datetime(2015, 1, 13, 0, 0),
#  datetime.datetime(2015, 1, 13, 1, 0),
#  datetime.datetime(2015, 1, 13, 2, 0),
#  datetime.datetime(2015, 1, 13, 3, 0),
#  datetime.datetime(2015, 1, 13, 4, 0),
#  datetime.datetime(2015, 1, 13, 5, 0),
#  datetime.datetime(2015, 1, 13, 6, 0),
#  datetime.datetime(2015, 1, 13, 7, 0),
#  datetime.datetime(2015, 1, 13, 8, 0),
#  datetime.datetime(2015, 1, 13, 9, 0),
#  datetime.datetime(2015, 1, 13, 10, 0),
#  datetime.datetime(2015, 1, 13, 11, 0),
#  datetime.datetime(2015, 1, 13, 12, 0),
#  datetime.datetime(2015, 1, 13, 13, 0),
#  datetime.datetime(2015, 1, 13, 14, 0),
#  datetime.datetime(2015, 1, 13, 15, 0),
#  datetime.datetime(2015, 1, 13, 16, 0),
#  datetime.datetime(2015, 1, 13, 17, 0),
#  datetime.datetime(2015, 1, 13, 18, 0),
#  datetime.datetime(2015, 1, 13, 19, 0),
#  datetime.datetime(2015, 1, 13, 20, 0),
#  datetime.datetime(2015, 1, 13, 21, 0),
#  datetime.datetime(2015, 1, 13, 22, 0),
#  datetime.datetime(2015, 1, 13, 23, 0),
#  datetime.datetime(2015, 1, 14, 0, 0),
#  datetime.datetime(2015, 1, 14, 1, 0),
#  datetime.datetime(2015, 1, 14, 2, 0),
#  datetime.datetime(2015, 1, 14, 3, 0),
#  datetime.datetime(2015, 1, 14, 4, 0),
#  datetime.datetime(2015, 1, 14, 5, 0),
#  datetime.datetime(2015, 1, 14, 6, 0),
#  datetime.datetime(2015, 1, 14, 7, 0),
#  datetime.datetime(2015, 1, 14, 8, 0),
#  datetime.datetime(2015, 1, 14, 9, 0),
#  datetime.datetime(2015, 1, 14, 10, 0),
#  datetime.datetime(2015, 1, 14, 11, 0),
#  datetime.datetime(2015, 1, 14, 12, 0),
#  datetime.datetime(2015, 1, 14, 13, 0),
#  datetime.datetime(2015, 1, 14, 14, 0),
#  datetime.datetime(2015, 1, 14, 15, 0),
#  datetime.datetime(2015, 1, 14, 16, 0),
#  datetime.datetime(2015, 1, 14, 17, 0),
#  datetime.datetime(2015, 1, 14, 18, 0),
#  datetime.datetime(2015, 1, 14, 19, 0),
#  datetime.datetime(2015, 1, 14, 20, 0),
#  datetime.datetime(2015, 1, 14, 21, 0),
#  datetime.datetime(2015, 1, 14, 22, 0),
#  datetime.datetime(2015, 1, 14, 23, 0),
#  datetime.datetime(2015, 1, 15, 0, 0),
#  datetime.datetime(2015, 1, 15, 1, 0),
#  datetime.datetime(2015, 1, 15, 2, 0),
#  datetime.datetime(2015, 1, 15, 3, 0),
#  datetime.datetime(2015, 1, 15, 4, 0),
#  datetime.datetime(2015, 1, 15, 5, 0),
#  datetime.datetime(2015, 1, 15, 6, 0),
#  datetime.datetime(2015, 1, 15, 7, 0),
#  datetime.datetime(2015, 1, 15, 8, 0),
#  datetime.datetime(2015, 1, 15, 9, 0),
#  datetime.datetime(2015, 1, 15, 10, 0),
#  datetime.datetime(2015, 1, 15, 11, 0),
#  datetime.datetime(2015, 1, 15, 12, 0),
#  datetime.datetime(2015, 1, 15, 13, 0),
#  datetime.datetime(2015, 1, 15, 14, 0),
#  datetime.datetime(2015, 1, 15, 15, 0),
#  datetime.datetime(2015, 1, 15, 16, 0),
#  datetime.datetime(2015, 1, 15, 17, 0),
#  datetime.datetime(2015, 1, 15, 18, 0),
#  datetime.datetime(2015, 1, 15, 19, 0),
#  datetime.datetime(2015, 1, 15, 20, 0),
#  datetime.datetime(2015, 1, 15, 21, 0),
#  datetime.datetime(2015, 1, 15, 22, 0),
#  datetime.datetime(2015, 1, 15, 23, 0),
#  datetime.datetime(2015, 1, 16, 0, 0),
#  datetime.datetime(2015, 1, 16, 1, 0),
#  datetime.datetime(2015, 1, 16, 2, 0),
#  datetime.datetime(2015, 1, 16, 3, 0),
#  datetime.datetime(2015, 1, 16, 4, 0),
#  datetime.datetime(2015, 1, 16, 5, 0),
#  datetime.datetime(2015, 1, 16, 6, 0),
#  datetime.datetime(2015, 1, 16, 7, 0),
#  datetime.datetime(2015, 1, 16, 8, 0),
#  datetime.datetime(2015, 1, 16, 9, 0),
#  datetime.datetime(2015, 1, 16, 10, 0),
#  datetime.datetime(2015, 1, 16, 11, 0),
#  datetime.datetime(2015, 1, 16, 12, 0),
#  datetime.datetime(2015, 1, 16, 13, 0),
#  datetime.datetime(2015, 1, 16, 14, 0),
#  datetime.datetime(2015, 1, 16, 15, 0),
#  datetime.datetime(2015, 1, 16, 16, 0),
#  datetime.datetime(2015, 1, 16, 17, 0),
#  datetime.datetime(2015, 1, 16, 18, 0),
#  datetime.datetime(2015, 1, 16, 19, 0),
#  datetime.datetime(2015, 1, 16, 20, 0),
#  datetime.datetime(2015, 1, 16, 21, 0),
#  datetime.datetime(2015, 1, 16, 22, 0),
#  datetime.datetime(2015, 1, 16, 23, 0),
#  datetime.datetime(2015, 1, 17, 0, 0),
#  datetime.datetime(2015, 1, 17, 1, 0),
#  datetime.datetime(2015, 1, 17, 2, 0),
#  datetime.datetime(2015, 1, 17, 3, 0),
#  datetime.datetime(2015, 1, 17, 4, 0),
#  datetime.datetime(2015, 1, 17, 5, 0),
#  datetime.datetime(2015, 1, 17, 6, 0),
#  datetime.datetime(2015, 1, 17, 7, 0),
#  datetime.datetime(2015, 1, 17, 8, 0),
#  datetime.datetime(2015, 1, 17, 9, 0),
#  datetime.datetime(2015, 1, 17, 10, 0),
#  datetime.datetime(2015, 1, 17, 11, 0),
#  datetime.datetime(2015, 1, 17, 12, 0),
#  datetime.datetime(2015, 1, 17, 13, 0),
#  datetime.datetime(2015, 1, 17, 14, 0),
#  datetime.datetime(2015, 1, 17, 15, 0),
#  datetime.datetime(2015, 1, 17, 16, 0),
#  datetime.datetime(2015, 1, 17, 17, 0),
#  datetime.datetime(2015, 1, 17, 18, 0),
#  datetime.datetime(2015, 1, 17, 19, 0),
#  datetime.datetime(2015, 1, 17, 20, 0),
#  datetime.datetime(2015, 1, 17, 21, 0),
#  datetime.datetime(2015, 1, 17, 22, 0),
#  datetime.datetime(2015, 1, 17, 23, 0),
#  datetime.datetime(2015, 1, 18, 0, 0),
#  datetime.datetime(2015, 1, 18, 1, 0),
#  datetime.datetime(2015, 1, 18, 2, 0),
#  datetime.datetime(2015, 1, 18, 3, 0),
#  datetime.datetime(2015, 1, 18, 4, 0),
#  datetime.datetime(2015, 1, 18, 5, 0),
#  datetime.datetime(2015, 1, 18, 6, 0),
#  datetime.datetime(2015, 1, 18, 7, 0),
#  datetime.datetime(2015, 1, 18, 8, 0),
#  datetime.datetime(2015, 1, 18, 9, 0),
#  datetime.datetime(2015, 1, 18, 10, 0),
#  datetime.datetime(2015, 1, 18, 11, 0),
#  datetime.datetime(2015, 1, 18, 12, 0),
#  datetime.datetime(2015, 1, 18, 13, 0),
#  datetime.datetime(2015, 1, 18, 14, 0),
#  datetime.datetime(2015, 1, 18, 15, 0),
#  datetime.datetime(2015, 1, 18, 16, 0),
#  datetime.datetime(2015, 1, 18, 17, 0),
#  datetime.datetime(2015, 1, 18, 18, 0),
#  datetime.datetime(2015, 1, 18, 19, 0),
#  datetime.datetime(2015, 1, 18, 20, 0),
#  datetime.datetime(2015, 1, 18, 21, 0),
#  datetime.datetime(2015, 1, 18, 22, 0),
#  datetime.datetime(2015, 1, 18, 23, 0),
#  datetime.datetime(2015, 1, 19, 0, 0),
#  datetime.datetime(2015, 1, 19, 1, 0),
#  datetime.datetime(2015, 1, 19, 2, 0),
#  datetime.datetime(2015, 1, 19, 3, 0),
#  datetime.datetime(2015, 1, 19, 4, 0),
#  datetime.datetime(2015, 1, 19, 5, 0),
#  datetime.datetime(2015, 1, 19, 6, 0),
#  datetime.datetime(2015, 1, 19, 7, 0),
#  datetime.datetime(2015, 1, 19, 8, 0),
#  datetime.datetime(2015, 1, 19, 9, 0),
#  datetime.datetime(2015, 1, 19, 10, 0),
#  datetime.datetime(2015, 1, 19, 11, 0),
#  datetime.datetime(2015, 1, 19, 12, 0),
#  datetime.datetime(2015, 1, 19, 13, 0),
#  datetime.datetime(2015, 1, 19, 14, 0),
#  datetime.datetime(2015, 1, 19, 15, 0),
#  datetime.datetime(2015, 1, 19, 16, 0),
#  datetime.datetime(2015, 1, 19, 17, 0),
#  datetime.datetime(2015, 1, 19, 18, 0),
#  datetime.datetime(2015, 1, 19, 19, 0),
#  datetime.datetime(2015, 1, 19, 20, 0),
#  datetime.datetime(2015, 1, 19, 21, 0),
#  datetime.datetime(2015, 1, 19, 22, 0),
#  datetime.datetime(2015, 1, 19, 23, 0),
#  datetime.datetime(2015, 1, 20, 0, 0),
#  datetime.datetime(2015, 1, 20, 1, 0),
#  datetime.datetime(2015, 1, 20, 2, 0),
#  datetime.datetime(2015, 1, 20, 3, 0),
#  datetime.datetime(2015, 1, 20, 4, 0),
#  datetime.datetime(2015, 1, 20, 5, 0),
#  datetime.datetime(2015, 1, 20, 6, 0),
#  datetime.datetime(2015, 1, 20, 7, 0),
#  datetime.datetime(2015, 1, 20, 8, 0),
#  datetime.datetime(2015, 1, 20, 9, 0),
#  datetime.datetime(2015, 1, 20, 10, 0),
#  datetime.datetime(2015, 1, 20, 11, 0),
#  datetime.datetime(2015, 1, 20, 12, 0),
#  datetime.datetime(2015, 1, 20, 13, 0),
#  datetime.datetime(2015, 1, 20, 14, 0),
#  datetime.datetime(2015, 1, 20, 15, 0),
#  datetime.datetime(2015, 1, 20, 16, 0),
#  datetime.datetime(2015, 1, 20, 17, 0),
#  datetime.datetime(2015, 1, 20, 18, 0),
#  datetime.datetime(2015, 1, 20, 19, 0),
#  datetime.datetime(2015, 1, 20, 20, 0),
#  datetime.datetime(2015, 1, 20, 21, 0),
#  datetime.datetime(2015, 1, 20, 22, 0),
#  datetime.datetime(2015, 1, 20, 23, 0),
#  datetime.datetime(2015, 1, 21, 0, 0),
#  datetime.datetime(2015, 1, 21, 1, 0),
#  datetime.datetime(2015, 1, 21, 2, 0),
#  datetime.datetime(2015, 1, 21, 3, 0),
#  datetime.datetime(2015, 1, 21, 4, 0),
#  datetime.datetime(2015, 1, 21, 5, 0),
#  datetime.datetime(2015, 1, 21, 6, 0),
#  datetime.datetime(2015, 1, 21, 7, 0),
#  datetime.datetime(2015, 1, 21, 8, 0),
#  datetime.datetime(2015, 1, 21, 9, 0),
#  datetime.datetime(2015, 1, 21, 10, 0),
#  datetime.datetime(2015, 1, 21, 11, 0),
#  datetime.datetime(2015, 1, 21, 12, 0),
#  datetime.datetime(2015, 1, 21, 13, 0),
#  datetime.datetime(2015, 1, 21, 14, 0),
#  datetime.datetime(2015, 1, 21, 15, 0),
#  datetime.datetime(2015, 1, 21, 16, 0),
#  datetime.datetime(2015, 1, 21, 17, 0),
#  datetime.datetime(2015, 1, 21, 18, 0),
#  datetime.datetime(2015, 1, 21, 19, 0),
#  datetime.datetime(2015, 1, 21, 20, 0),
#  datetime.datetime(2015, 1, 21, 21, 0),
#  datetime.datetime(2015, 1, 21, 22, 0),
#  datetime.datetime(2015, 1, 21, 23, 0),
#  datetime.datetime(2015, 1, 22, 0, 0),
#  datetime.datetime(2015, 1, 22, 1, 0),
#  datetime.datetime(2015, 1, 22, 2, 0),
#  datetime.datetime(2015, 1, 22, 3, 0),
#  datetime.datetime(2015, 1, 22, 4, 0),
#  datetime.datetime(2015, 1, 22, 5, 0),
#  datetime.datetime(2015, 1, 22, 6, 0),
#  datetime.datetime(2015, 1, 22, 7, 0),
#  datetime.datetime(2015, 1, 22, 8, 0),
#  datetime.datetime(2015, 1, 22, 9, 0),
#  datetime.datetime(2015, 1, 22, 10, 0),
#  datetime.datetime(2015, 1, 22, 11, 0),
#  datetime.datetime(2015, 1, 22, 12, 0),
#  datetime.datetime(2015, 1, 22, 13, 0),
#  datetime.datetime(2015, 1, 22, 14, 0),
#  datetime.datetime(2015, 1, 22, 15, 0),
#  datetime.datetime(2015, 1, 22, 16, 0),
#  datetime.datetime(2015, 1, 22, 17, 0),
#  datetime.datetime(2015, 1, 22, 18, 0),
#  datetime.datetime(2015, 1, 22, 19, 0),
#  datetime.datetime(2015, 1, 22, 20, 0),
#  datetime.datetime(2015, 1, 22, 21, 0),
#  datetime.datetime(2015, 1, 22, 22, 0),
#  datetime.datetime(2015, 1, 22, 23, 0),
#  datetime.datetime(2015, 1, 23, 0, 0),
#  datetime.datetime(2015, 1, 23, 1, 0),
#  datetime.datetime(2015, 1, 23, 2, 0),
#  datetime.datetime(2015, 1, 23, 3, 0),
#  datetime.datetime(2015, 1, 23, 4, 0),
#  datetime.datetime(2015, 1, 23, 5, 0),
#  datetime.datetime(2015, 1, 23, 6, 0),
#  datetime.datetime(2015, 1, 23, 7, 0),
#  datetime.datetime(2015, 1, 23, 8, 0),
#  datetime.datetime(2015, 1, 23, 9, 0),
#  datetime.datetime(2015, 1, 23, 10, 0),
#  datetime.datetime(2015, 1, 23, 11, 0),
#  datetime.datetime(2015, 1, 23, 12, 0),
#  datetime.datetime(2015, 1, 23, 13, 0),
#  datetime.datetime(2015, 1, 23, 14, 0),
#  datetime.datetime(2015, 1, 23, 15, 0),
#  datetime.datetime(2015, 1, 23, 16, 0),
#  datetime.datetime(2015, 1, 23, 17, 0),
#  datetime.datetime(2015, 1, 23, 18, 0),
#  datetime.datetime(2015, 1, 23, 19, 0),
#  datetime.datetime(2015, 1, 23, 20, 0),
#  datetime.datetime(2015, 1, 23, 21, 0),
#  datetime.datetime(2015, 1, 23, 22, 0),
#  datetime.datetime(2015, 1, 23, 23, 0),
#  datetime.datetime(2015, 1, 24, 0, 0),
#  datetime.datetime(2015, 1, 24, 1, 0),
#  datetime.datetime(2015, 1, 24, 2, 0),
#  datetime.datetime(2015, 1, 24, 3, 0),
#  datetime.datetime(2015, 1, 24, 4, 0),
#  datetime.datetime(2015, 1, 24, 5, 0),
#  datetime.datetime(2015, 1, 24, 6, 0),
#  datetime.datetime(2015, 1, 24, 7, 0),
#  datetime.datetime(2015, 1, 24, 8, 0),
#  datetime.datetime(2015, 1, 24, 9, 0),
#  datetime.datetime(2015, 1, 24, 10, 0),
#  datetime.datetime(2015, 1, 24, 11, 0),
#  datetime.datetime(2015, 1, 24, 12, 0),
#  datetime.datetime(2015, 1, 24, 13, 0),
#  datetime.datetime(2015, 1, 24, 14, 0),
#  datetime.datetime(2015, 1, 24, 15, 0),
#  datetime.datetime(2015, 1, 24, 16, 0),
#  datetime.datetime(2015, 1, 24, 17, 0),
#  datetime.datetime(2015, 1, 24, 18, 0),
#  datetime.datetime(2015, 1, 24, 19, 0),
#  datetime.datetime(2015, 1, 24, 20, 0),
#  datetime.datetime(2015, 1, 24, 21, 0),
#  datetime.datetime(2015, 1, 24, 22, 0),
#  datetime.datetime(2015, 1, 24, 23, 0),
#  datetime.datetime(2015, 1, 25, 0, 0),
#  datetime.datetime(2015, 1, 25, 1, 0),
#  datetime.datetime(2015, 1, 25, 2, 0),
#  datetime.datetime(2015, 1, 25, 3, 0),
#  datetime.datetime(2015, 1, 25, 4, 0),
#  datetime.datetime(2015, 1, 25, 5, 0),
#  datetime.datetime(2015, 1, 25, 6, 0),
#  datetime.datetime(2015, 1, 25, 7, 0),
#  datetime.datetime(2015, 1, 25, 8, 0),
#  datetime.datetime(2015, 1, 25, 9, 0),
#  datetime.datetime(2015, 1, 25, 10, 0),
#  datetime.datetime(2015, 1, 25, 11, 0),
#  datetime.datetime(2015, 1, 25, 12, 0),
#  datetime.datetime(2015, 1, 25, 13, 0),
#  datetime.datetime(2015, 1, 25, 14, 0),
#  datetime.datetime(2015, 1, 25, 15, 0),
#  datetime.datetime(2015, 1, 25, 16, 0),
#  datetime.datetime(2015, 1, 25, 17, 0),
#  datetime.datetime(2015, 1, 25, 18, 0),
#  datetime.datetime(2015, 1, 25, 19, 0),
#  datetime.datetime(2015, 1, 25, 20, 0),
#  datetime.datetime(2015, 1, 25, 21, 0),
#  datetime.datetime(2015, 1, 25, 22, 0),
#  datetime.datetime(2015, 1, 25, 23, 0),
#  datetime.datetime(2015, 1, 26, 0, 0),
#  datetime.datetime(2015, 1, 26, 1, 0),
#  datetime.datetime(2015, 1, 26, 2, 0),
#  datetime.datetime(2015, 1, 26, 3, 0),
#  datetime.datetime(2015, 1, 26, 4, 0),
#  datetime.datetime(2015, 1, 26, 5, 0),
#  datetime.datetime(2015, 1, 26, 6, 0),
#  datetime.datetime(2015, 1, 26, 7, 0),
#  datetime.datetime(2015, 1, 26, 8, 0),
#  datetime.datetime(2015, 1, 26, 9, 0),
#  datetime.datetime(2015, 1, 26, 10, 0),
#  datetime.datetime(2015, 1, 26, 11, 0),
#  datetime.datetime(2015, 1, 26, 12, 0),
#  datetime.datetime(2015, 1, 26, 13, 0),
#  datetime.datetime(2015, 1, 26, 14, 0),
#  datetime.datetime(2015, 1, 26, 15, 0),
#  datetime.datetime(2015, 1, 26, 16, 0),
#  datetime.datetime(2015, 1, 26, 17, 0),
#  datetime.datetime(2015, 1, 26, 18, 0),
#  datetime.datetime(2015, 1, 26, 19, 0),
#  datetime.datetime(2015, 1, 26, 20, 0),
#  datetime.datetime(2015, 1, 26, 21, 0),
#  datetime.datetime(2015, 1, 26, 22, 0),
#  datetime.datetime(2015, 1, 26, 23, 0),
#  datetime.datetime(2015, 1, 27, 0, 0),
#  datetime.datetime(2015, 1, 27, 1, 0),
#  datetime.datetime(2015, 1, 27, 2, 0),
#  datetime.datetime(2015, 1, 27, 3, 0),
#  datetime.datetime(2015, 1, 27, 4, 0),
#  datetime.datetime(2015, 1, 27, 5, 0),
#  datetime.datetime(2015, 1, 27, 6, 0),
#  datetime.datetime(2015, 1, 27, 7, 0),
#  datetime.datetime(2015, 1, 27, 8, 0),
#  datetime.datetime(2015, 1, 27, 9, 0),
#  datetime.datetime(2015, 1, 27, 10, 0),
#  datetime.datetime(2015, 1, 27, 11, 0),
#  datetime.datetime(2015, 1, 27, 12, 0),
#  datetime.datetime(2015, 1, 27, 13, 0),
#  datetime.datetime(2015, 1, 27, 14, 0),
#  datetime.datetime(2015, 1, 27, 15, 0),
#  datetime.datetime(2015, 1, 27, 16, 0),
#  datetime.datetime(2015, 1, 27, 17, 0),
#  datetime.datetime(2015, 1, 27, 18, 0),
#  datetime.datetime(2015, 1, 27, 19, 0),
#  datetime.datetime(2015, 1, 27, 20, 0),
#  datetime.datetime(2015, 1, 27, 21, 0),
#  datetime.datetime(2015, 1, 27, 22, 0),
#  datetime.datetime(2015, 1, 27, 23, 0),
#  datetime.datetime(2015, 1, 28, 0, 0),
#  datetime.datetime(2015, 1, 28, 1, 0),
#  datetime.datetime(2015, 1, 28, 2, 0),
#  datetime.datetime(2015, 1, 28, 3, 0),
#  datetime.datetime(2015, 1, 28, 4, 0),
#  datetime.datetime(2015, 1, 28, 5, 0),
#  datetime.datetime(2015, 1, 28, 6, 0),
#  datetime.datetime(2015, 1, 28, 7, 0),
#  datetime.datetime(2015, 1, 28, 8, 0),
#  datetime.datetime(2015, 1, 28, 9, 0),
#  datetime.datetime(2015, 1, 28, 10, 0),
#  datetime.datetime(2015, 1, 28, 11, 0),
#  datetime.datetime(2015, 1, 28, 12, 0),
#  datetime.datetime(2015, 1, 28, 13, 0),
#  datetime.datetime(2015, 1, 28, 14, 0),
#  datetime.datetime(2015, 1, 28, 15, 0),
#  datetime.datetime(2015, 1, 28, 16, 0),
#  datetime.datetime(2015, 1, 28, 17, 0),
#  datetime.datetime(2015, 1, 28, 18, 0),
#  datetime.datetime(2015, 1, 28, 19, 0),
#  datetime.datetime(2015, 1, 28, 20, 0),
#  datetime.datetime(2015, 1, 28, 21, 0),
#  datetime.datetime(2015, 1, 28, 22, 0),
#  datetime.datetime(2015, 1, 28, 23, 0),
#  datetime.datetime(2015, 1, 29, 0, 0),
#  datetime.datetime(2015, 1, 29, 1, 0),
#  datetime.datetime(2015, 1, 29, 2, 0),
#  datetime.datetime(2015, 1, 29, 3, 0),
#  datetime.datetime(2015, 1, 29, 4, 0),
#  datetime.datetime(2015, 1, 29, 5, 0),
#  datetime.datetime(2015, 1, 29, 6, 0),
#  datetime.datetime(2015, 1, 29, 7, 0),
#  datetime.datetime(2015, 1, 29, 8, 0),
#  datetime.datetime(2015, 1, 29, 9, 0),
#  datetime.datetime(2015, 1, 29, 10, 0),
#  datetime.datetime(2015, 1, 29, 11, 0),
#  datetime.datetime(2015, 1, 29, 12, 0),
#  datetime.datetime(2015, 1, 29, 13, 0),
#  datetime.datetime(2015, 1, 29, 14, 0),
#  datetime.datetime(2015, 1, 29, 15, 0),
#  datetime.datetime(2015, 1, 29, 16, 0),
#  datetime.datetime(2015, 1, 29, 17, 0),
#  datetime.datetime(2015, 1, 29, 18, 0),
#  datetime.datetime(2015, 1, 29, 19, 0),
#  datetime.datetime(2015, 1, 29, 20, 0),
#  datetime.datetime(2015, 1, 29, 21, 0),
#  datetime.datetime(2015, 1, 29, 22, 0),
#  datetime.datetime(2015, 1, 29, 23, 0),
#  datetime.datetime(2015, 1, 30, 0, 0),
#  datetime.datetime(2015, 1, 30, 1, 0),
#  datetime.datetime(2015, 1, 30, 2, 0),
#  datetime.datetime(2015, 1, 30, 3, 0),
#  datetime.datetime(2015, 1, 30, 4, 0),
#  datetime.datetime(2015, 1, 30, 5, 0),
#  datetime.datetime(2015, 1, 30, 6, 0),
#  datetime.datetime(2015, 1, 30, 7, 0),
#  datetime.datetime(2015, 1, 30, 8, 0),
#  datetime.datetime(2015, 1, 30, 9, 0),
#  datetime.datetime(2015, 1, 30, 10, 0),
#  datetime.datetime(2015, 1, 30, 11, 0),
#  datetime.datetime(2015, 1, 30, 12, 0),
#  datetime.datetime(2015, 1, 30, 13, 0),
#  datetime.datetime(2015, 1, 30, 14, 0),
#  datetime.datetime(2015, 1, 30, 15, 0),
#  datetime.datetime(2015, 1, 30, 16, 0),
#  datetime.datetime(2015, 1, 30, 17, 0),
#  datetime.datetime(2015, 1, 30, 18, 0),
#  datetime.datetime(2015, 1, 30, 19, 0),
#  datetime.datetime(2015, 1, 30, 20, 0),
#  datetime.datetime(2015, 1, 30, 21, 0),
#  datetime.datetime(2015, 1, 30, 22, 0),
#  datetime.datetime(2015, 1, 30, 23, 0),
#  datetime.datetime(2015, 1, 31, 0, 0),
#  datetime.datetime(2015, 1, 31, 1, 0),
#  datetime.datetime(2015, 1, 31, 2, 0),
#  datetime.datetime(2015, 1, 31, 3, 0),
#  datetime.datetime(2015, 1, 31, 4, 0),
#  datetime.datetime(2015, 1, 31, 5, 0),
#  datetime.datetime(2015, 1, 31, 6, 0),
#  datetime.datetime(2015, 1, 31, 7, 0),
#  datetime.datetime(2015, 1, 31, 8, 0),
#  datetime.datetime(2015, 1, 31, 9, 0),
#  datetime.datetime(2015, 1, 31, 10, 0),
#  datetime.datetime(2015, 1, 31, 11, 0),
#  datetime.datetime(2015, 1, 31, 12, 0),
#  datetime.datetime(2015, 1, 31, 13, 0),
#  datetime.datetime(2015, 1, 31, 14, 0),
#  datetime.datetime(2015, 1, 31, 15, 0),
#  datetime.datetime(2015, 1, 31, 16, 0),
#  datetime.datetime(2015, 1, 31, 17, 0),
#  datetime.datetime(2015, 1, 31, 18, 0),
#  datetime.datetime(2015, 1, 31, 19, 0),
#  datetime.datetime(2015, 1, 31, 20, 0),
#  datetime.datetime(2015, 1, 31, 21, 0),
#  datetime.datetime(2015, 1, 31, 22, 0),
#  datetime.datetime(2015, 1, 31, 23, 0),
#  datetime.datetime(2015, 2, 1, 0, 0),
#  datetime.datetime(2015, 2, 1, 1, 0),
#  datetime.datetime(2015, 2, 1, 2, 0),
#  datetime.datetime(2015, 2, 1, 3, 0),
#  datetime.datetime(2015, 2, 1, 4, 0),
#  datetime.datetime(2015, 2, 1, 5, 0),
#  datetime.datetime(2015, 2, 1, 6, 0),
#  datetime.datetime(2015, 2, 1, 7, 0),
#  datetime.datetime(2015, 2, 1, 8, 0),
#  datetime.datetime(2015, 2, 1, 9, 0),
#  datetime.datetime(2015, 2, 1, 10, 0),
#  datetime.datetime(2015, 2, 1, 11, 0),
#  datetime.datetime(2015, 2, 1, 12, 0),
#  datetime.datetime(2015, 2, 1, 13, 0),
#  datetime.datetime(2015, 2, 1, 14, 0),
#  datetime.datetime(2015, 2, 1, 15, 0),
#  datetime.datetime(2015, 2, 1, 16, 0),
#  datetime.datetime(2015, 2, 1, 17, 0),
#  datetime.datetime(2015, 2, 1, 18, 0),
#  datetime.datetime(2015, 2, 1, 19, 0),
#  datetime.datetime(2015, 2, 1, 20, 0),
#  datetime.datetime(2015, 2, 1, 21, 0),
#  datetime.datetime(2015, 2, 1, 22, 0),
#  datetime.datetime(2015, 2, 1, 23, 0),
#  datetime.datetime(2015, 2, 2, 0, 0),
#  datetime.datetime(2015, 2, 2, 1, 0),
#  datetime.datetime(2015, 2, 2, 2, 0),
#  datetime.datetime(2015, 2, 2, 3, 0),
#  datetime.datetime(2015, 2, 2, 4, 0),
#  datetime.datetime(2015, 2, 2, 5, 0),
#  datetime.datetime(2015, 2, 2, 6, 0),
#  datetime.datetime(2015, 2, 2, 7, 0),
#  datetime.datetime(2015, 2, 2, 8, 0),
#  datetime.datetime(2015, 2, 2, 9, 0),
#  datetime.datetime(2015, 2, 2, 10, 0),
#  datetime.datetime(2015, 2, 2, 11, 0),
#  datetime.datetime(2015, 2, 2, 12, 0),
#  datetime.datetime(2015, 2, 2, 13, 0),
#  datetime.datetime(2015, 2, 2, 14, 0),
#  datetime.datetime(2015, 2, 2, 15, 0),
#  datetime.datetime(2015, 2, 2, 16, 0),
#  datetime.datetime(2015, 2, 2, 17, 0),
#  datetime.datetime(2015, 2, 2, 18, 0),
#  datetime.datetime(2015, 2, 2, 19, 0),
#  datetime.datetime(2015, 2, 2, 20, 0),
#  datetime.datetime(2015, 2, 2, 21, 0),
#  datetime.datetime(2015, 2, 2, 22, 0),
#  datetime.datetime(2015, 2, 2, 23, 0),
#  datetime.datetime(2015, 2, 3, 0, 0),
#  datetime.datetime(2015, 2, 3, 1, 0),
#  datetime.datetime(2015, 2, 3, 2, 0),
#  datetime.datetime(2015, 2, 3, 3, 0),
#  datetime.datetime(2015, 2, 3, 4, 0),
#  datetime.datetime(2015, 2, 3, 5, 0),
#  datetime.datetime(2015, 2, 3, 6, 0),
#  datetime.datetime(2015, 2, 3, 7, 0),
#  datetime.datetime(2015, 2, 3, 8, 0),
#  datetime.datetime(2015, 2, 3, 9, 0),
#  datetime.datetime(2015, 2, 3, 10, 0),
#  datetime.datetime(2015, 2, 3, 11, 0),
#  datetime.datetime(2015, 2, 3, 12, 0),
#  datetime.datetime(2015, 2, 3, 13, 0),
#  datetime.datetime(2015, 2, 3, 14, 0),
#  datetime.datetime(2015, 2, 3, 15, 0),
#  datetime.datetime(2015, 2, 3, 16, 0),
#  datetime.datetime(2015, 2, 3, 17, 0),
#  datetime.datetime(2015, 2, 3, 18, 0),
#  datetime.datetime(2015, 2, 3, 19, 0),
#  datetime.datetime(2015, 2, 3, 20, 0),
#  datetime.datetime(2015, 2, 3, 21, 0),
#  datetime.datetime(2015, 2, 3, 22, 0),
#  datetime.datetime(2015, 2, 3, 23, 0),
#  datetime.datetime(2015, 2, 4, 0, 0),
#  datetime.datetime(2015, 2, 4, 1, 0),
#  datetime.datetime(2015, 2, 4, 2, 0),
#  datetime.datetime(2015, 2, 4, 3, 0),
#  datetime.datetime(2015, 2, 4, 4, 0),
#  datetime.datetime(2015, 2, 4, 5, 0),
#  datetime.datetime(2015, 2, 4, 6, 0),
#  datetime.datetime(2015, 2, 4, 7, 0),
#  datetime.datetime(2015, 2, 4, 8, 0),
#  datetime.datetime(2015, 2, 4, 9, 0),
#  datetime.datetime(2015, 2, 4, 10, 0),
#  datetime.datetime(2015, 2, 4, 11, 0),
#  datetime.datetime(2015, 2, 4, 12, 0),
#  datetime.datetime(2015, 2, 4, 13, 0),
#  datetime.datetime(2015, 2, 4, 14, 0),
#  datetime.datetime(2015, 2, 4, 15, 0),
#  datetime.datetime(2015, 2, 4, 16, 0),
#  datetime.datetime(2015, 2, 4, 17, 0),
#  datetime.datetime(2015, 2, 4, 18, 0),
#  datetime.datetime(2015, 2, 4, 19, 0),
#  datetime.datetime(2015, 2, 4, 20, 0),
#  datetime.datetime(2015, 2, 4, 21, 0),
#  datetime.datetime(2015, 2, 4, 22, 0),
#  datetime.datetime(2015, 2, 4, 23, 0),
#  datetime.datetime(2015, 2, 5, 0, 0),
#  datetime.datetime(2015, 2, 5, 1, 0),
#  datetime.datetime(2015, 2, 5, 2, 0),
#  datetime.datetime(2015, 2, 5, 3, 0),
#  datetime.datetime(2015, 2, 5, 4, 0),
#  datetime.datetime(2015, 2, 5, 5, 0),
#  datetime.datetime(2015, 2, 5, 6, 0),
#  datetime.datetime(2015, 2, 5, 7, 0),
#  datetime.datetime(2015, 2, 5, 8, 0),
#  datetime.datetime(2015, 2, 5, 9, 0),
#  datetime.datetime(2015, 2, 5, 10, 0),
#  datetime.datetime(2015, 2, 5, 11, 0),
#  datetime.datetime(2015, 2, 5, 12, 0),
#  datetime.datetime(2015, 2, 5, 13, 0),
#  datetime.datetime(2015, 2, 5, 14, 0),
#  datetime.datetime(2015, 2, 5, 15, 0),
#  datetime.datetime(2015, 2, 5, 16, 0),
#  datetime.datetime(2015, 2, 5, 17, 0),
#  datetime.datetime(2015, 2, 5, 18, 0),
#  datetime.datetime(2015, 2, 5, 19, 0),
#  datetime.datetime(2015, 2, 5, 20, 0),
#  datetime.datetime(2015, 2, 5, 21, 0),
#  datetime.datetime(2015, 2, 5, 22, 0),
#  datetime.datetime(2015, 2, 5, 23, 0),
#  datetime.datetime(2015, 2, 6, 0, 0),
#  datetime.datetime(2015, 2, 6, 1, 0),
#  datetime.datetime(2015, 2, 6, 2, 0),
#  datetime.datetime(2015, 2, 6, 3, 0),
#  datetime.datetime(2015, 2, 6, 4, 0),
#  datetime.datetime(2015, 2, 6, 5, 0),
#  datetime.datetime(2015, 2, 6, 6, 0),
#  datetime.datetime(2015, 2, 6, 7, 0),
#  datetime.datetime(2015, 2, 6, 8, 0),
#  datetime.datetime(2015, 2, 6, 9, 0),
#  datetime.datetime(2015, 2, 6, 10, 0),
#  datetime.datetime(2015, 2, 6, 11, 0),
#  datetime.datetime(2015, 2, 6, 12, 0),
#  datetime.datetime(2015, 2, 6, 13, 0),
#  datetime.datetime(2015, 2, 6, 14, 0),
#  datetime.datetime(2015, 2, 6, 15, 0),
#  datetime.datetime(2015, 2, 6, 16, 0),
#  datetime.datetime(2015, 2, 6, 17, 0),
#  datetime.datetime(2015, 2, 6, 18, 0),
#  datetime.datetime(2015, 2, 6, 19, 0),
#  datetime.datetime(2015, 2, 6, 20, 0),
#  datetime.datetime(2015, 2, 6, 21, 0),
#  datetime.datetime(2015, 2, 6, 22, 0),
#  datetime.datetime(2015, 2, 6, 23, 0),
#  datetime.datetime(2015, 2, 7, 0, 0),
#  datetime.datetime(2015, 2, 7, 1, 0),
#  datetime.datetime(2015, 2, 7, 2, 0),
#  datetime.datetime(2015, 2, 7, 3, 0),
#  datetime.datetime(2015, 2, 7, 4, 0),
#  datetime.datetime(2015, 2, 7, 5, 0),
#  datetime.datetime(2015, 2, 7, 6, 0),
#  datetime.datetime(2015, 2, 7, 7, 0),
#  datetime.datetime(2015, 2, 7, 8, 0),
#  datetime.datetime(2015, 2, 7, 9, 0),
#  datetime.datetime(2015, 2, 7, 10, 0),
#  datetime.datetime(2015, 2, 7, 11, 0),
#  datetime.datetime(2015, 2, 7, 12, 0),
#  datetime.datetime(2015, 2, 7, 13, 0),
#  datetime.datetime(2015, 2, 7, 14, 0),
#  datetime.datetime(2015, 2, 7, 15, 0),
#  datetime.datetime(2015, 2, 7, 16, 0),
#  datetime.datetime(2015, 2, 7, 17, 0),
#  datetime.datetime(2015, 2, 7, 18, 0),
#  datetime.datetime(2015, 2, 7, 19, 0),
#  datetime.datetime(2015, 2, 7, 20, 0),
#  datetime.datetime(2015, 2, 7, 21, 0),
#  datetime.datetime(2015, 2, 7, 22, 0),
#  datetime.datetime(2015, 2, 7, 23, 0),
#  datetime.datetime(2015, 2, 8, 0, 0),
#  datetime.datetime(2015, 2, 8, 1, 0),
#  datetime.datetime(2015, 2, 8, 2, 0),
#  datetime.datetime(2015, 2, 8, 3, 0),
#  datetime.datetime(2015, 2, 8, 4, 0),
#  datetime.datetime(2015, 2, 8, 5, 0),
#  datetime.datetime(2015, 2, 8, 6, 0),
#  datetime.datetime(2015, 2, 8, 7, 0),
#  datetime.datetime(2015, 2, 8, 8, 0),
#  datetime.datetime(2015, 2, 8, 9, 0),
#  datetime.datetime(2015, 2, 8, 10, 0),
#  datetime.datetime(2015, 2, 8, 11, 0),
#  datetime.datetime(2015, 2, 8, 12, 0),
#  datetime.datetime(2015, 2, 8, 13, 0),
#  datetime.datetime(2015, 2, 8, 14, 0),
#  datetime.datetime(2015, 2, 8, 15, 0),
#  datetime.datetime(2015, 2, 8, 16, 0),
#  datetime.datetime(2015, 2, 8, 17, 0),
#  datetime.datetime(2015, 2, 8, 18, 0),
#  datetime.datetime(2015, 2, 8, 19, 0),
#  datetime.datetime(2015, 2, 8, 20, 0),
#  datetime.datetime(2015, 2, 8, 21, 0),
#  datetime.datetime(2015, 2, 8, 22, 0),
#  datetime.datetime(2015, 2, 8, 23, 0),
#  datetime.datetime(2015, 2, 9, 0, 0),
#  datetime.datetime(2015, 2, 9, 1, 0),
#  datetime.datetime(2015, 2, 9, 2, 0),
#  datetime.datetime(2015, 2, 9, 3, 0),
#  datetime.datetime(2015, 2, 9, 4, 0),
#  datetime.datetime(2015, 2, 9, 5, 0),
#  datetime.datetime(2015, 2, 9, 6, 0),
#  datetime.datetime(2015, 2, 9, 7, 0),
#  datetime.datetime(2015, 2, 9, 8, 0),
#  datetime.datetime(2015, 2, 9, 9, 0),
#  datetime.datetime(2015, 2, 9, 10, 0),
#  datetime.datetime(2015, 2, 9, 11, 0),
#  datetime.datetime(2015, 2, 9, 12, 0),
#  datetime.datetime(2015, 2, 9, 13, 0),
#  datetime.datetime(2015, 2, 9, 14, 0),
#  datetime.datetime(2015, 2, 9, 15, 0),
#  datetime.datetime(2015, 2, 9, 16, 0),
#  datetime.datetime(2015, 2, 9, 17, 0),
#  datetime.datetime(2015, 2, 9, 18, 0),
#  datetime.datetime(2015, 2, 9, 19, 0),
#  datetime.datetime(2015, 2, 9, 20, 0),
#  datetime.datetime(2015, 2, 9, 21, 0),
#  datetime.datetime(2015, 2, 9, 22, 0),
#  datetime.datetime(2015, 2, 9, 23, 0),
#  datetime.datetime(2015, 2, 10, 0, 0),
#  datetime.datetime(2015, 2, 10, 1, 0),
#  datetime.datetime(2015, 2, 10, 2, 0),
#  datetime.datetime(2015, 2, 10, 3, 0),
#  datetime.datetime(2015, 2, 10, 4, 0),
#  datetime.datetime(2015, 2, 10, 5, 0),
#  datetime.datetime(2015, 2, 10, 6, 0),
#  datetime.datetime(2015, 2, 10, 7, 0),
#  datetime.datetime(2015, 2, 10, 8, 0),
#  datetime.datetime(2015, 2, 10, 9, 0),
#  datetime.datetime(2015, 2, 10, 10, 0),
#  datetime.datetime(2015, 2, 10, 11, 0),
#  datetime.datetime(2015, 2, 10, 12, 0),
#  datetime.datetime(2015, 2, 10, 13, 0),
#  datetime.datetime(2015, 2, 10, 14, 0),
#  datetime.datetime(2015, 2, 10, 15, 0),
#  datetime.datetime(2015, 2, 10, 16, 0),
#  datetime.datetime(2015, 2, 10, 17, 0),
#  datetime.datetime(2015, 2, 10, 18, 0),
#  datetime.datetime(2015, 2, 10, 19, 0),
#  datetime.datetime(2015, 2, 10, 20, 0),
#  datetime.datetime(2015, 2, 10, 21, 0),
#  datetime.datetime(2015, 2, 10, 22, 0),
#  datetime.datetime(2015, 2, 10, 23, 0),
#  datetime.datetime(2015, 2, 11, 0, 0),
#  datetime.datetime(2015, 2, 11, 1, 0),
#  datetime.datetime(2015, 2, 11, 2, 0),
#  datetime.datetime(2015, 2, 11, 3, 0),
#  datetime.datetime(2015, 2, 11, 4, 0),
#  datetime.datetime(2015, 2, 11, 5, 0),
#  datetime.datetime(2015, 2, 11, 6, 0),
#  datetime.datetime(2015, 2, 11, 7, 0),
#  datetime.datetime(2015, 2, 11, 8, 0),
#  datetime.datetime(2015, 2, 11, 9, 0),
#  datetime.datetime(2015, 2, 11, 10, 0),
#  datetime.datetime(2015, 2, 11, 11, 0),
#  datetime.datetime(2015, 2, 11, 12, 0),
#  datetime.datetime(2015, 2, 11, 13, 0),
#  datetime.datetime(2015, 2, 11, 14, 0),
#  datetime.datetime(2015, 2, 11, 15, 0),
#  datetime.datetime(2015, 2, 11, 16, 0),
#  datetime.datetime(2015, 2, 11, 17, 0),
#  datetime.datetime(2015, 2, 11, 18, 0),
#  datetime.datetime(2015, 2, 11, 19, 0),
#  datetime.datetime(2015, 2, 11, 20, 0),
#  datetime.datetime(2015, 2, 11, 21, 0),
#  datetime.datetime(2015, 2, 11, 22, 0),
#  datetime.datetime(2015, 2, 11, 23, 0),
#  ...]

# %%
tide_analysis(study_points[0], ftimes, fpreds)
# Out:
# (1.4020440000000001, -1.842122, 3.2441659999999999, 15)

# %%
study_tides = list(map(tide_analysis, study_points))
control_tides = list(map(tide_analysis, control_points))

# %%
st_Ms = [k[0] for k in study_tides]
st_ms = [k[1] for k in study_tides]
st_As = [k[2] for k in study_tides]
st_phis = [k[3] for k in study_tides]

# %%
ct_Ms = [k[0] for k in control_tides]
ct_ms = [k[1] for k in control_tides]
ct_As = [k[2] for k in control_tides]
ct_phis = [k[3] for k in control_tides]

# %%
fig, axs = plt.subplots(1,1, figsize = (30,20))

fig.suptitle('Tidal analysis for \n June 1 - September 30', size = 40)

labels = ('Other trajectories', 'Southern trajectories')
colors = ['b','r']

titles = ['Maxs(m)', 'Mins(m)', 'Amplitudes(m)', 'Phase (h)']
sts = [st_Ms, st_ms, st_As, st_phis]
cts = [ct_Ms, ct_ms, ct_As, ct_phis]




for i in range (4):
    axs[i].tick_params(labelsize = 30,)

    control_group = cts[i]
    study_group = sts[i]

    groups = [control_group, study_group]


    axs[i].hist(
            groups, 
            color= colors, 
            alpha=0.8, 
            normed = True,
            label = labels, 
            )
    
    plt.legend(loc = 0)
    
    axs[i].set_ylabel ("Percentage of trajectories", size = 20)
    axs[i].set_xlabel (titles[i], size = 30)




plt.tight_layout()
# Out:
# /ocean/gsgarbi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
len(groups[0])
# Out:
# 155088

# %%
plot_tanalysis(cts, sts, 0)

# %%
plot_tanalysis(cts, sts, 1)

# %%
plot_tanalysis(cts, sts, 2)

# %%
plot_tanalysis(cts, sts, 3, normed = True)
